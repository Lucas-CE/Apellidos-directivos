# %% [markdown]
# # **Preprocesamiento de nombres de directivos**

# %%
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, FewShotChatMessagePromptTemplate
import dotenv
import os
from pydantic import BaseModel
import unicodedata
import re
from typing import Optional

# %% [markdown]
# ### **Carga de datos**

# %%
dotenv.load_dotenv()
API_KEY = os.getenv("OPENAI_API_KEY")

# %%
df = pd.read_csv('data/directors_and_companies.csv')
df.head()
# Out:
#   Rut_individuo                       Nombre       Cargo Fecha_nombramiento  \
# 0           0-E     LUIS ORVAÑANOS LASCURAIN  Presidente         28/03/2012
# 1           0-E  EMILIO CUENCA FRIEDERICHSEN    Director         28/03/2012
# 2           0-E      ROBERTO ORVAÑANOS CONDE    Director         28/03/2012
# 3           0-E     IÑIGO ORVAÑANOS CORCUERA    Director         28/03/2012
# 4           0-E          RAUL ZORRILLA COSIO    Director         28/03/2012
#
#   Fecha_termino  Rut_Empresa                   Nombre_empresa
# 0           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.
# 1           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.
# 2           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.
# 3           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.
# 4           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.

# %% [markdown]
# ### **Limpiamos los nombres de los directivos**

# %%
def clean_name(name: str):
    capital_name = name.strip().upper()
    clean_name = unicodedata.normalize('NFD', capital_name).encode('ascii', 'ignore').decode('utf-8')
    clean_name = re.sub(r'[^a-zA-Z0-9\s]', '', clean_name)
    return clean_name

df['Nombre'] = df['Nombre'].apply(clean_name)
df.head()
# Out:
#   Rut_individuo                       Nombre       Cargo Fecha_nombramiento  \
# 0           0-E     LUIS ORVANANOS LASCURAIN  Presidente         28/03/2012
# 1           0-E  EMILIO CUENCA FRIEDERICHSEN    Director         28/03/2012
# 2           0-E      ROBERTO ORVANANOS CONDE    Director         28/03/2012
# 3           0-E     INIGO ORVANANOS CORCUERA    Director         28/03/2012
# 4           0-E          RAUL ZORRILLA COSIO    Director         28/03/2012
#
#   Fecha_termino  Rut_Empresa                   Nombre_empresa
# 0           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.
# 1           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.
# 2           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.
# 3           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.
# 4           NaN     59175530  CORPORACION GEO, S.A.B. DE C.V.

# %% [markdown]
# ### **Eliminar duplicados**

# %%
company_names_df = df[['Nombre', 'Nombre_empresa']].dropna(subset=['Nombre_empresa', 'Nombre'])
company_names_df.shape
# Out:
# (15841, 2)

# %%
company_names_df_without_duplicates = company_names_df.drop_duplicates()
print(f"Shape without duplicates: {company_names_df_without_duplicates.shape}")
company_names_df_without_duplicates.head()
# Out:
# Shape without duplicates: (6946, 2)
#                         Nombre                   Nombre_empresa
# 0     LUIS ORVANANOS LASCURAIN  CORPORACION GEO, S.A.B. DE C.V.
# 1  EMILIO CUENCA FRIEDERICHSEN  CORPORACION GEO, S.A.B. DE C.V.
# 2      ROBERTO ORVANANOS CONDE  CORPORACION GEO, S.A.B. DE C.V.
# 3     INIGO ORVANANOS CORCUERA  CORPORACION GEO, S.A.B. DE C.V.
# 4          RAUL ZORRILLA COSIO  CORPORACION GEO, S.A.B. DE C.V.

# %% [markdown]
# ### **Separamos los nombres y apellidos de los directivos**

# %%
class NombreDirectivo(BaseModel):
    """
    Nombre de un directivo
    """
    nombres: str
    primer_apellido: str
    segundo_apellido: str

# %%
examples = [
    {
        "input": "Separa el nombre y los apellidos de: Lucas Carrasco Estay",
        "output": {"nombres": "Lucas", "primer_apellido": "Carrasco", "segundo_apellido": "Estay"}
    },
    {
        "input": "Separa el nombre y los apellidos de: Juan Pablo González",
        "output": {"nombres": "Juan Pablo", "primer_apellido": "González", "segundo_apellido": ""}
    },
    {
        "input": "Separa el nombre y los apellidos de: Maria Garcia Fernandez de Leon",
        "output": {"nombres": "Maria", "primer_apellido": "Garcia", "segundo_apellido": "Fernandez de Leon"}
    },
    {
        "input": "Separa el nombre y los apellidos de: Juan Carlos de la Torre",
        "output": {"nombres": "Juan Carlos", "primer_apellido": "de la Torre", "segundo_apellido": ""}
    },
]

example_prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}"),
        ("ai", "{output}"),
    ]
)
few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_prompt,
    examples=examples,
)

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "Eres un experto en separar nombres y apellidos."),
        few_shot_prompt,
        ("user", "Separa el nombre y los apellidos de: {name}"),
    ]
)

# %%
model = ChatOpenAI(
    openai_api_key=API_KEY, 
    model="gpt-4o-mini",
)
structured_llm = model.with_structured_output(NombreDirectivo)

chain = prompt | structured_llm
chain
# Out:
# ChatPromptTemplate(input_variables=['name'], messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='Eres un experto en separar nombres y apellidos.')), FewShotChatMessagePromptTemplate(examples=[{'input': 'Separa el nombre y los apellidos de: Lucas Carrasco Estay', 'output': {'nombres': 'Lucas', 'primer_apellido': 'Carrasco', 'segundo_apellido': 'Estay'}}, {'input': 'Separa el nombre y los apellidos de: Juan Pablo González', 'output': {'nombres': 'Juan Pablo', 'primer_apellido': 'González', 'segundo_apellido': ''}}, {'input': 'Separa el nombre y los apellidos de: Maria Garcia Fernandez de Leon', 'output': {'nombres': 'Maria', 'primer_apellido': 'Garcia', 'segundo_apellido': 'Fernandez de Leon'}}, {'input': 'Separa el nombre y los apellidos de: Juan Carlos de la Torre', 'output': {'nombres': 'Juan Carlos', 'primer_apellido': 'de la Torre', 'segundo_apellido': ''}}], example_prompt=ChatPromptTemplate(input_variables=['input', 'output'], messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}')), AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=['output'], template='{output}'))])), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['name'], template='Separa el nombre y los apellidos de: {name}'))])
# | RunnableBinding(bound=ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x00000208BB29D940>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x00000208BB29ECF0>, model_name='gpt-4o-mini', openai_api_key=SecretStr('**********'), openai_proxy=''), kwargs={'tools': [{'type': 'function', 'function': {'name': 'NombreDirectivo', 'description': 'Nombre de un directivo', 'parameters': {'type': 'object', 'properties': {'nombres': {'type': 'string'}, 'primer_apellido': {'type': 'string'}, 'segundo_apellido': {'type': 'string'}}, 'required': ['nombres', 'primer_apellido', 'segundo_apellido']}}}], 'tool_choice': {'type': 'function', 'function': {'name': 'NombreDirectivo'}}})
# | JsonOutputKeyToolsParser(first_tool_only=True, key_name='NombreDirectivo')

# %%
nombres = []
primer_apellidos = []
segundo_apellidos = []
for index, row in company_names_df_without_duplicates.iterrows():
    response = chain.invoke({"name": row['Nombre']})
    print(f"Nombre: {row['Nombre']}, Response: {response}")
    nombres.append(response['nombres'])
    primer_apellidos.append(response['primer_apellido'])
    segundo_apellidos.append(response['segundo_apellido'])
    
company_names_df_without_duplicates['Nombres'] = nombres
company_names_df_without_duplicates['Primer_apellido'] = primer_apellidos
company_names_df_without_duplicates['Segundo_apellido'] = segundo_apellidos
company_names_df_without_duplicates.head()
# Out:
# Nombre: LUIS ORVANANOS LASCURAIN, Response: {'nombres': 'LUIS', 'primer_apellido': 'ORVANANOS', 'segundo_apellido': 'LASCURAIN'}
# Nombre: EMILIO CUENCA FRIEDERICHSEN, Response: {'nombres': 'EMILIO', 'primer_apellido': 'CUENCA', 'segundo_apellido': 'FRIEDERICHSEN'}
# Nombre: ROBERTO ORVANANOS CONDE, Response: {'nombres': 'ROBERTO', 'primer_apellido': 'ORVANANOS', 'segundo_apellido': 'CONDE'}
# Nombre: INIGO ORVANANOS CORCUERA, Response: {'nombres': 'INIGO', 'primer_apellido': 'ORVANANOS', 'segundo_apellido': 'CORCUERA'}
# Nombre: RAUL ZORRILLA COSIO, Response: {'nombres': 'RAUL', 'primer_apellido': 'ZORRILLA', 'segundo_apellido': 'COSIO'}
# Nombre: LUIS IGNACIO ADJELJALEK MARTINEZ, Response: {'nombres': 'LUIS IGNACIO', 'primer_apellido': 'ADJELJALEK', 'segundo_apellido': 'MARTINEZ'}
# Nombre: ANDRES CAIRE OBREGON, Response: {'nombres': 'ANDRES', 'primer_apellido': 'CAIRE', 'segundo_apellido': 'OBREGON'}
# Nombre: GABRIEL GOMEZ CASTANARES, Response: {'nombres': 'GABRIEL', 'primer_apellido': 'GOMEZ', 'segundo_apellido': 'CASTANARES'}
# Nombre: FRANCISCO GIL DIAZ, Response: {'nombres': 'FRANCISCO', 'primer_apellido': 'GIL', 'segundo_apellido': 'DIAZ'}
# Nombre: JOSE CARRAL ESCALANTE, Response: {'nombres': 'JOSE', 'primer_apellido': 'CARRAL', 'segundo_apellido': 'ESCALANTE'}
# Nombre: TOMAS LOZANO MOLINA, Response: {'nombres': 'TOMAS', 'primer_apellido': 'LOZANO', 'segundo_apellido': 'MOLINA'}
# Nombre: ALBERTO GUILLERMO SAAVEDRA OLAVARRIETA, Response: {'nombres': 'ALBERTO GUILLERMO', 'primer_apellido': 'SAAVEDRA', 'segundo_apellido': 'OLAVARRIETA'}
# Nombre: ALVARO GASCA NERI, Response: {'nombres': 'ALVARO', 'primer_apellido': 'GASCA', 'segundo_apellido': 'NERI'}
# Nombre: MANUEL WEINBERG LOPEZ, Response: {'nombres': 'MANUEL', 'primer_apellido': 'WEINBERG', 'segundo_apellido': 'LOPEZ'}
# Nombre: ROBERTO ALCANTARA ROJAS, Response: {'nombres': 'ROBERTO', 'primer_apellido': 'ALCANTARA', 'segundo_apellido': 'ROJAS'}
# Nombre: JUAN PABLO ROSAS PEREZ, Response: {'nombres': 'JUAN PABLO', 'primer_apellido': 'ROSAS', 'segundo_apellido': 'PEREZ'}
# Nombre: LLOYD BLANKFEIN , Response: {'nombres': 'LLOYD', 'primer_apellido': 'BLANKFEIN', 'segundo_apellido': ''}
# Nombre: MICHELE BURNS , Response: {'nombres': 'MICHELE', 'primer_apellido': 'BURNS', 'segundo_apellido': ''}
# Nombre: GARY COHN , Response: {'nombres': 'GARY', 'primer_apellido': 'COHN', 'segundo_apellido': ''}
# Nombre: CLAES DAHLBACK , Response: {'nombres': 'CLAES', 'primer_apellido': 'DAHLBACK', 'segundo_apellido': ''}
# Nombre: WILLIAM GEORGE , Response: {'nombres': 'WILLIAM GEORGE', 'primer_apellido': '', 'segundo_apellido': ''}
# Nombre: JAMES JOHNSON , Response: {'nombres': 'JAMES', 'primer_apellido': 'JOHNSON', 'segundo_apellido': ''}
# Nombre: LAKSHMI MITTAL , Response: {'nombres': 'LAKSHMI', 'primer_apellido': 'MITTAL', 'segundo_apellido': ''}
# Nombre: ADEBAYO OGUNLESI , Response: {'nombres': 'ADEBAYO', 'primer_apellido': 'OGUNLESI', 'segundo_apellido': ''}
# Nombre: PETER OPPENHEIMER , Response: {'nombres': 'PETER', 'primer_apellido': 'OPPENHEIMER', 'segundo_apellido': ''}
# Nombre: JAMES SCHIRO , Response: {'nombres': 'JAMES', 'primer_apellido': 'SCHIRO', 'segundo_apellido': ''}
# Nombre: DEBORA SPAR , Response: {'nombres': 'DEBORA', 'primer_apellido': 'SPAR', 'segundo_apellido': ''}
# Nombre: MARK TUCKER , Response: {'nombres': 'MARK', 'primer_apellido': 'TUCKER', 'segundo_apellido': ''}
# Nombre: DAVID VINIAR , Response: {'nombres': 'DAVID', 'primer_apellido': 'VINIAR', 'segundo_apellido': ''}
# Nombre: ARMANDO VALDIVIESO MONTES, Response: {'nombres': 'ARMANDO', 'primer_apellido': 'VALDIVIESO', 'segundo_apellido': 'MONTES'}
# Nombre: LYSETTE HENRIQUEZ AMESTOY, Response: {'nombres': 'LYSETTE', 'primer_apellido': 'HENRIQUEZ', 'segundo_apellido': 'AMESTOY'}
# Nombre: MARIA SUSANA CAREY CLARO, Response: {'nombres': 'MARIA SUSANA', 'primer_apellido': 'CAREY', 'segundo_apellido': 'CLARO'}
# Nombre: PATRICIO FRANCISCO ARRAU PONS, Response: {'nombres': 'PATRICIO FRANCISCO', 'primer_apellido': 'ARRAU', 'segundo_apellido': 'PONS'}
# Nombre: CAROLINA DEL PILAR BUSTOS RUBIO, Response: {'nombres': 'CAROLINA DEL PILAR', 'primer_apellido': 'BUSTOS', 'segundo_apellido': 'RUBIO'}
# Nombre: CRISTIAN PALMA ARANCIBIA, Response: {'nombres': 'CRISTIAN', 'primer_apellido': 'PALMA', 'segundo_apellido': 'ARANCIBIA'}
# Nombre: ANDRES PALMA IRARRAZABAL, Response: {'nombres': 'ANDRES', 'primer_apellido': 'PALMA', 'segundo_apellido': 'IRARRAZABAL'}
# Nombre: JORGE ALEJANDRO ALVAREZ ARAVENA, Response: {'nombres': 'JORGE ALEJANDRO', 'primer_apellido': 'ALVAREZ', 'segundo_apellido': 'ARAVENA'}
# Nombre: CAROLINA IRENE ETEROVIC SUDY, Response: {'nombres': 'CAROLINA IRENE', 'primer_apellido': 'ETEROVIC', 'segundo_apellido': 'SUDY'}
# Nombre: EUGENIO RODOLFO PIES FUENZALIDA, Response: {'nombres': 'EUGENIO RODOLFO', 'primer_apellido': 'PIES', 'segundo_apellido': 'FUENZALIDA'}
# Nombre: SUSANA ELENA SIERRA LEWIN, Response: {'nombres': 'SUSANA ELENA', 'primer_apellido': 'SIERRA', 'segundo_apellido': 'LEWIN'}
# Nombre: IVAN MESIAS LEHU, Response: {'nombres': 'IVAN', 'primer_apellido': 'MESIAS', 'segundo_apellido': 'LEHU'}
# Nombre: VERONICA MONTELLANO CANTUARIAS, Response: {'nombres': 'VERONICA', 'primer_apellido': 'MONTELLANO', 'segundo_apellido': 'CANTUARIAS'}
# Nombre: ENRIQUE ROMAN GONZALEZ, Response: {'nombres': 'ENRIQUE ROMAN', 'primer_apellido': 'GONZALEZ', 'segundo_apellido': ''}
# Nombre: LUIS CORDERO VEGA, Response: {'nombres': 'LUIS', 'primer_apellido': 'CORDERO', 'segundo_apellido': 'VEGA'}
# Nombre: OSCAR ELTIT SPIELMANN, Response: {'nombres': 'OSCAR ELTIT', 'primer_apellido': 'SPIELMANN', 'segundo_apellido': ''}
# Nombre: ROBERTO CIFUENTES ALLEL, Response: {'nombres': 'ROBERTO', 'primer_apellido': 'CIFUENTES', 'segundo_apellido': 'ALLEL'}
# Nombre: OSCAR SANTELICES ALTAMIRANO, Response: {'nombres': 'OSCAR', 'primer_apellido': 'SANTELICES', 'segundo_apellido': 'ALTAMIRANO'}
# Nombre: ANTONIO RECABARREN MEDEIROS, Response: {'nombres': 'ANTONIO', 'primer_apellido': 'RECABARREN', 'segundo_apellido': 'MEDEIROS'}
# Nombre: EDUARDO ANTONIO BIZAMA CABALA, Response: {'nombres': 'EDUARDO ANTONIO', 'primer_apellido': 'BIZAMA', 'segundo_apellido': 'CABALA'}
# Nombre: ARTURO BERNARDO MERINO NUNEZ, Response: {'nombres': 'ARTURO BERNARDO', 'primer_apellido': 'MERINO', 'segundo_apellido': 'NUNEZ'}
# Nombre: JORGE ROBLES MELLA, Response: {'nombres': 'JORGE', 'primer_apellido': 'ROBLES', 'segundo_apellido': 'MELLA'}
# Nombre: CARLOS MLADINIC ALONSO, Response: {'nombres': 'CARLOS', 'primer_apellido': 'MLADINIC', 'segundo_apellido': 'ALONSO'}
# Nombre: HUGO EDUARDO RODRIGUEZ GONZALEZ, Response: {'nombres': 'HUGO EDUARDO', 'primer_apellido': 'RODRIGUEZ', 'segundo_apellido': 'GONZALEZ'}
# Nombre: HENRY CLEVELAND CARTES, Response: {'nombres': 'HENRY CLEVELAND', 'primer_apellido': 'CARTES', 'segundo_apellido': ''}
# Nombre: CARLOS PATRICIO KETTERER DROGHETTI, Response: {'nombres': 'CARLOS PATRICIO', 'primer_apellido': 'KETTERER', 'segundo_apellido': 'DROGHETTI'}
# Nombre: CRISTIAN PABLO PIZARRO STIEPOVICH, Response: {'nombres': 'CRISTIAN PABLO', 'primer_apellido': 'PIZARRO', 'segundo_apellido': 'STIEPOVICH'}
# Nombre: MANUEL SAINZ SALAS, Response: {'nombres': 'MANUEL', 'primer_apellido': 'SAINZ', 'segundo_apellido': 'SALAS'}
# Nombre: MARIO MORAGA TRESCKOW, Response: {'nombres': 'MARIO', 'primer_apellido': 'MORAGA', 'segundo_apellido': 'TRESCKOW'}
# Nombre: JORGE GEBAUER BITTNER, Response: {'nombres': 'JORGE', 'primer_apellido': 'GEBAUER', 'segundo_apellido': 'BITTNER'}
# Nombre: PEDRO PABLO ERRAZURIZ DOMINGUEZ, Response: {'nombres': 'PEDRO PABLO', 'primer_apellido': 'ERRAZURIZ', 'segundo_apellido': 'DOMINGUEZ'}
# Nombre: GERMAN CORREA DIAZ, Response: {'nombres': 'GERMAN', 'primer_apellido': 'CORREA', 'segundo_apellido': 'DIAZ'}
# Nombre: JORGE IVAN INOSTROZA SANCHEZ, Response: {'nombres': 'JORGE IVAN', 'primer_apellido': 'INOSTROZA', 'segundo_apellido': 'SANCHEZ'}
# Nombre: JOAQUIN IGNACIO BRAHM BARRIL, Response: {'nombres': 'JOAQUIN IGNACIO', 'primer_apellido': 'BRAHM', 'segundo_apellido': 'BARRIL'}
# Nombre: VICTOR TOLEDO SANDOVAL, Response: {'nombres': 'VICTOR', 'primer_apellido': 'TOLEDO', 'segundo_apellido': 'SANDOVAL'}
# Nombre: CRISTIAN ANDRES URETA LARRAIN, Response: {'nombres': 'CRISTIAN ANDRES', 'primer_apellido': 'URETA', 'segundo_apellido': 'LARRAIN'}
# Nombre: DAVID ENRIQUE GUZMAN SILVA, Response: {'nombres': 'DAVID ENRIQUE', 'primer_apellido': 'GUZMAN', 'segundo_apellido': 'SILVA'}
# Nombre: CRISTIAN SOLIS DE OVANDO LAVIN, Response: {'nombres': 'CRISTIAN', 'primer_apellido': 'SOLIS DE OVANDO', 'segundo_apellido': 'LAVIN'}
# Nombre: MARIA EUGENIA TORRES HENRIQUEZ, Response: {'nombres': 'MARIA EUGENIA', 'primer_apellido': 'TORRES', 'segundo_apellido': 'HENRIQUEZ'}
# Nombre: ADRIANA BRANCOLI POBLETE, Response: {'nombres': 'ADRIANA', 'primer_apellido': 'BRANCOLI', 'segundo_apellido': 'POBLETE'}
# Nombre: ISABEL MARGARITA ROMERO MUNOZ, Response: {'nombres': 'ISABEL MARGARITA', 'primer_apellido': 'ROMERO', 'segundo_apellido': 'MUNOZ'}
# Nombre: MARIA VERONICA MORALES MENA, Response: {'nombres': 'MARIA VERONICA', 'primer_apellido': 'MORALES', 'segundo_apellido': 'MENA'}
# Nombre: MARIA CECILIA GODOY CRUZ, Response: {'nombres': 'MARIA CECILIA', 'primer_apellido': 'GODOY', 'segundo_apellido': 'CRUZ'}
# Nombre: OSVALDO PABLO LAGOS PUCCIO, Response: {'nombres': 'OSVALDO PABLO', 'primer_apellido': 'LAGOS', 'segundo_apellido': 'PUCCIO'}
# Nombre: MARCELA GUZMAN SALAZAR, Response: {'nombres': 'MARCELA', 'primer_apellido': 'GUZMAN', 'segundo_apellido': 'SALAZAR'}
# Nombre: OSCAR CARLOS PELUCHONNEAU CONTRERAS, Response: {'nombres': 'OSCAR CARLOS', 'primer_apellido': 'PELUCHONNEAU', 'segundo_apellido': 'CONTRERAS'}
# Nombre: JOSE MIGUEL CRUZ GONZALEZ, Response: {'nombres': 'JOSE MIGUEL', 'primer_apellido': 'CRUZ', 'segundo_apellido': 'GONZALEZ'}
# Nombre: MAGDALENA MARIA FREI LARRAECHEA, Response: {'nombres': 'MAGDALENA MARIA', 'primer_apellido': 'FREI', 'segundo_apellido': 'LARRAECHEA'}
# Nombre: LUIS HORACIO ROJAS MANCILLA, Response: {'nombres': 'LUIS HORACIO', 'primer_apellido': 'ROJAS', 'segundo_apellido': 'MANCILLA'}
# Nombre: RAFAEL ELEODORO ALDUNATE VALDES, Response: {'nombres': 'RAFAEL ELEODORO', 'primer_apellido': 'ALDUNATE', 'segundo_apellido': 'VALDES'}
# Nombre: JOSE LUIS DOMINGUEZ COVARRUBIAS, Response: {'nombres': 'JOSE LUIS', 'primer_apellido': 'DOMINGUEZ', 'segundo_apellido': 'COVARRUBIAS'}
# Nombre: CRISTIAN HUMBERTO VALENZUELA ARAYA, Response: {'nombres': 'CRISTIAN HUMBERTO', 'primer_apellido': 'VALENZUELA', 'segundo_apellido': 'ARAYA'}
# Nombre: JORGE OMAR ALE YARAD, Response: {'nombres': 'JORGE OMAR', 'primer_apellido': 'ALE', 'segundo_apellido': 'YARAD'}
# Nombre: CLAUDIO SEEBACH SPEISER, Response: {'nombres': 'CLAUDIO', 'primer_apellido': 'SEEBACH', 'segundo_apellido': 'SPEISER'}
# Nombre: JORGE CLAUDIO RETAMAL RUBIO, Response: {'nombres': 'JORGE CLAUDIO', 'primer_apellido': 'RETAMAL', 'segundo_apellido': 'RUBIO'}
# Nombre: IGNACIO PIO ANTONIO BASCUNAN OCHAGAVIA, Response: {'nombres': 'IGNACIO PIO ANTONIO', 'primer_apellido': 'BASCUNAN', 'segundo_apellido': 'OCHAGAVIA'}
# Nombre: FRANCISCO REYES SILVA, Response: {'nombres': 'FRANCISCO', 'primer_apellido': 'REYES', 'segundo_apellido': 'SILVA'}
# Nombre: ANA BEATRIZ HOLUIGUE BARROS, Response: {'nombres': 'ANA BEATRIZ', 'primer_apellido': 'HOLUIGUE', 'segundo_apellido': 'BARROS'}
# Nombre: GONZALO EDWARDS GUZMAN, Response: {'nombres': 'Gonzalo Edwards', 'primer_apellido': 'Guzman', 'segundo_apellido': ''}
# Nombre: SERGIO SAMUEL URZUA SOZA, Response: {'nombres': 'SERGIO SAMUEL', 'primer_apellido': 'URZUA', 'segundo_apellido': 'SOZA'}
# Nombre: JUAN ESTEBAN DONA NOVOA, Response: {'nombres': 'JUAN ESTEBAN', 'primer_apellido': 'DONA', 'segundo_apellido': 'NOVOA'}
# Nombre: RAPHAEL BERGOEING VELA, Response: {'nombres': 'RAPHAEL', 'primer_apellido': 'BERGOEING', 'segundo_apellido': 'VELA'}
# Nombre: ALEJANDRO VALENZUELA DIEZ, Response: {'nombres': 'ALEJANDRO', 'primer_apellido': 'VALENZUELA', 'segundo_apellido': 'DIEZ'}
# Nombre: LOUIS DE GRANGE CONCHA, Response: {'nombres': 'LOUIS', 'primer_apellido': 'DE GRANGE', 'segundo_apellido': 'CONCHA'}
# Nombre: RODRIGO CRISTOBAL AZOCAR HIDALGO, Response: {'nombres': 'RODRIGO CRISTOBAL', 'primer_apellido': 'AZOCAR', 'segundo_apellido': 'HIDALGO'}
# Nombre: ALDO GONZALEZ TISSINETTI, Response: {'nombres': 'ALDO', 'primer_apellido': 'GONZALEZ', 'segundo_apellido': 'TISSINETTI'}
# Nombre: FERNANDO ENRIQUE CANAS BERKOWITZ, Response: {'nombres': 'FERNANDO ENRIQUE', 'primer_apellido': 'CANAS', 'segundo_apellido': 'BERKOWITZ'}
# Nombre: RAPHAEL BERGOEING VELA, Response: {'nombres': 'RAPHAEL', 'primer_apellido': 'BERGOEING', 'segundo_apellido': 'VELA'}
# Nombre: NICOLE KELLER FLATEN, Response: {'nombres': 'NICOLE', 'primer_apellido': 'KELLER', 'segundo_apellido': 'FLATEN'}
# Nombre: PAULINA SORIANO FUENZALIDA, Response: {'nombres': 'PAULINA', 'primer_apellido': 'SORIANO', 'segundo_apellido': 'FUENZALIDA'}
# Nombre: JOSE LUIS DOMINGUEZ COVARRUBIAS, Response: {'nombres': 'JOSE LUIS', 'primer_apellido': 'DOMINGUEZ', 'segundo_apellido': 'COVARRUBIAS'}
# Nombre: ARTURO GANA DE LANDA, Response: {'nombres': 'ARTURO', 'primer_apellido': 'GANA', 'segundo_apellido': 'DE LANDA'}
# Nombre: LUZ GRANIER BULNES, Response: {'nombres': 'LUZ', 'primer_apellido': 'GRANIER', 'segundo_apellido': 'BULNES'}
# Nombre: JUAN CARLOS HERRERA MALDONADO, Response: {'nombres': 'JUAN CARLOS', 'primer_apellido': 'HERRERA', 'segundo_apellido': 'MALDONADO'}
# Nombre: GERMAN CONCHA ZAVALA, Response: {'nombres': 'GERMAN', 'primer_apellido': 'CONCHA', 'segundo_apellido': 'ZAVALA'}
# Nombre: ANDREA SALOMON DUMMER, Response: {'nombres': 'ANDREA', 'primer_apellido': 'SALOMON', 'segundo_apellido': 'DUMMER'}
# Nombre: KAREN PONIACHIK POLLAK, Response: {'nombres': 'KAREN', 'primer_apellido': 'PONIACHIK', 'segundo_apellido': 'POLLAK'}
# Nombre: CARLOS MLADINIC ALONSO, Response: {'nombres': 'CARLOS', 'primer_apellido': 'MLADINIC', 'segundo_apellido': 'ALONSO'}
# Nombre: VICENTE PARDO DIAZ, Response: {'nombres': 'VICENTE', 'primer_apellido': 'PARDO', 'segundo_apellido': 'DIAZ'}
# Nombre: MARCELA ADRIANA MUNIZAGA MUNOZ, Response: {'nombres': 'MARCELA ADRIANA', 'primer_apellido': 'MUNIZAGA', 'segundo_apellido': 'MUNOZ'}
# Nombre: VLADIMIR GLASINOVIC PENA, Response: {'nombres': 'VLADIMIR', 'primer_apellido': 'GLASINOVIC', 'segundo_apellido': 'PENA'}
# Nombre: CLAUDIO SOTO GAMBOA, Response: {'nombres': 'CLAUDIO', 'primer_apellido': 'SOTO', 'segundo_apellido': 'GAMBOA'}
# Nombre: JUAN CARLOS MUNOZ ABOGABIR, Response: {'nombres': 'JUAN CARLOS', 'primer_apellido': 'MUNOZ', 'segundo_apellido': 'ABOGABIR'}
# Nombre: FRANCISCO JAVIER SILVA DONOSO, Response: {'nombres': 'FRANCISCO JAVIER', 'primer_apellido': 'SILVA', 'segundo_apellido': 'DONOSO'}
# Nombre: BERNARDO FONTAINE TALAVERA, Response: {'nombres': 'BERNARDO', 'primer_apellido': 'FONTAINE', 'segundo_apellido': 'TALAVERA'}
# Nombre: DOMINGO EDMUNDO ARTEAGA ECHEVERRIA, Response: {'nombres': 'DOMINGO EDMUNDO', 'primer_apellido': 'ARTEAGA', 'segundo_apellido': 'ECHEVERRIA'}
# Nombre: CLEMENTE JOSE PEREZ ERRAZURIZ, Response: {'nombres': 'CLEMENTE JOSE', 'primer_apellido': 'PEREZ', 'segundo_apellido': 'ERRAURIZ'}
# Nombre: ORLANDO CHACRA CORVILLON, Response: {'nombres': 'ORLANDO', 'primer_apellido': 'CHACRA', 'segundo_apellido': 'CORVILLON'}
# Nombre: CARLOS GONZALO ZEPEDA HERNANDEZ, Response: {'nombres': 'CARLOS GONZALO', 'primer_apellido': 'ZEPEDA', 'segundo_apellido': 'HERNANDEZ'}
# Nombre: VERONICA EDWARDS GUZMAN, Response: {'nombres': 'VERONICA', 'primer_apellido': 'EDWARDS', 'segundo_apellido': 'GUZMAN'}
# Nombre: JOSE FERNANDO AGUIRRE DIAZ, Response: {'nombres': 'JOSE FERNANDO', 'primer_apellido': 'AGUIRRE', 'segundo_apellido': 'DIAZ'}
# Nombre: OSCAR LANDERRETCHE MORENO, Response: {'nombres': 'OSCAR', 'primer_apellido': 'LANDERRETCHE', 'segundo_apellido': 'MORENO'}
# Nombre: DANTE CONTRERAS GUAJARDO, Response: {'nombres': 'DANTE', 'primer_apellido': 'CONTRERAS', 'segundo_apellido': 'GUAJARDO'}
# Nombre: FERNANDO EMILIO PORCILE VALENZUELA, Response: {'nombres': 'FERNANDO EMILIO', 'primer_apellido': 'PORCILE', 'segundo_apellido': 'VALENZUELA'}
# Nombre: ISIDORO PALMA PENCO, Response: {'nombres': 'ISIDORO', 'primer_apellido': 'PALMA', 'segundo_apellido': 'PENCO'}
# Nombre: JUAN ENRIQUE MORALES JARAMILLO, Response: {'nombres': 'JUAN ENRIQUE', 'primer_apellido': 'MORALES', 'segundo_apellido': 'JARAMILLO'}
# Nombre: RADOMIRO BLAS TOMIC ERRAZURIZ, Response: {'nombres': 'RADOMIRO BLAS', 'primer_apellido': 'TOMIC', 'segundo_apellido': 'ERRAZURIZ'}
# Nombre: JUAN BENAVIDES FELIU, Response: {'nombres': 'JUAN', 'primer_apellido': 'BENAVIDES', 'segundo_apellido': 'FELIU'}
# Nombre: HERNAN DE SOLMINIHAC TAMPIER, Response: {'nombres': 'HERNAN', 'primer_apellido': 'DE SOLMINIHAC', 'segundo_apellido': 'TAMPIER'}
# Nombre: PAUL SCHIODTZ OBILINOVICH, Response: {'nombres': 'PAUL', 'primer_apellido': 'SCHIODTZ', 'segundo_apellido': 'OBILINOVICH'}
# Nombre: RODRIGO ANDRES CERDA NORAMBUENA, Response: {'nombres': 'RODRIGO ANDRES', 'primer_apellido': 'CERDA', 'segundo_apellido': 'NORAMBUENA'}
# Nombre: GHASSAN DAYOUB PSELI, Response: {'nombres': 'GHASSAN DAYOUB', 'primer_apellido': 'PSELI', 'segundo_apellido': ''}
# Nombre: RAIMUNDO ESPINOZA CONCHA, Response: {'nombres': 'RAIMUNDO', 'primer_apellido': 'ESPINOZA', 'segundo_apellido': 'CONCHA'}
# Nombre: IGNACIO BRIONES ROJAS, Response: {'nombres': 'IGNACIO', 'primer_apellido': 'BRIONES', 'segundo_apellido': 'ROJAS'}
# Nombre: LAURA ALBORNOZ POLLMANN, Response: {'nombres': 'LAURA', 'primer_apellido': 'ALBORNOZ', 'segundo_apellido': 'POLLMANN'}
# Nombre: JUAN GERARDO JOFRE MIRANDA, Response: {'nombres': 'JUAN GERARDO', 'primer_apellido': 'JOFRE', 'segundo_apellido': 'MIRANDA'}
# Nombre: MARCOS MANUEL LIMA ARAVENA, Response: {'nombres': 'MARCOS MANUEL', 'primer_apellido': 'LIMA', 'segundo_apellido': 'ARAVENA'}
# Nombre: AUGUSTO GONZALEZ AGUIRRE, Response: {'nombres': 'AUGUSTO', 'primer_apellido': 'GONZALEZ', 'segundo_apellido': 'AGUIRRE'}
# Nombre: MARCOS BUCHI BUC, Response: {'nombres': 'MARCOS', 'primer_apellido': 'BUCHI', 'segundo_apellido': 'BUC'}
# Nombre: JUAN LUIS OSSA BULNES, Response: {'nombres': 'JUAN LUIS', 'primer_apellido': 'OSSA', 'segundo_apellido': 'BULNES'}
# Nombre: ANDRES TAGLE DOMINGUEZ, Response: {'nombres': 'ANDRES', 'primer_apellido': 'TAGLE', 'segundo_apellido': 'DOMINGUEZ'}
# Nombre: JORGE ARTURO BANDE BRUCK, Response: {'nombres': 'JORGE ARTURO', 'primer_apellido': 'BANDE', 'segundo_apellido': 'BRUCK'}
# Nombre: IGNACIO HERNAN TORRES CABELLO, Response: {'nombres': 'IGNACIO HERNAN', 'primer_apellido': 'TORRES', 'segundo_apellido': 'CABELLO'}
# Nombre: JAIME ROBERTO GUTIERREZ CASTILLO, Response: {'nombres': 'JAIME ROBERTO', 'primer_apellido': 'GUTIERREZ', 'segundo_apellido': 'CASTILLO'}
# Nombre: CLAUDIO MUNOZ ZUNIGA, Response: {'nombres': 'CLAUDIO', 'primer_apellido': 'MUNOZ', 'segundo_apellido': 'ZUNIGA'}
# Nombre: GUILLERMO PICKERING DE LA FUENTE, Response: {'nombres': 'GUILLERMO', 'primer_apellido': 'PICKERING', 'segundo_apellido': 'DE LA FUENTE'}
# Nombre: FELIPE LARRAIN ASPILLAGA, Response: {'nombres': 'FELIPE', 'primer_apellido': 'LARRAIN', 'segundo_apellido': 'ASPILLAGA'}
# Nombre: JOAQUIN VILLARINO HERRERA, Response: {'nombres': 'JOAQUIN', 'primer_apellido': 'VILLARINO', 'segundo_apellido': 'HERRERA'}
# Nombre: HERMAN CHADWICK PINERA, Response: {'nombres': 'HERMAN', 'primer_apellido': 'CHADWICK', 'segundo_apellido': 'PINERA'}
# Nombre: JOSEP BAGUE PRATS, Response: {'nombres': 'JOSEP', 'primer_apellido': 'BAGUE', 'segundo_apellido': 'PRATS'}
# Nombre: PATRICIO PRIETO SANCHEZ, Response: {'nombres': 'PATRICIO', 'primer_apellido': 'PRIETO', 'segundo_apellido': 'SANCHEZ'}
# Nombre: LUIS ALEJANDRO MAYOL BOUCHON, Response: {'nombres': 'LUIS ALEJANDRO', 'primer_apellido': 'MAYOL', 'segundo_apellido': 'BOUCHON'}
# Nombre: RODRIGO MANUBENS MOLTEDO, Response: {'nombres': 'RODRIGO MANUBENS', 'primer_apellido': 'MOLTEDO', 'segundo_apellido': ''}
# Nombre: MARIA LORETO SILVA ROJAS, Response: {'nombres': 'MARIA LORETO', 'primer_apellido': 'SILVA', 'segundo_apellido': 'ROJAS'}
# Nombre: GIORGIANNA CUNEO QUEIROLO, Response: {'nombres': 'GIORGIANNA', 'primer_apellido': 'CUNEO', 'segundo_apellido': 'QUEIROLO'}
# Nombre: NARCISO BERBERANA SAENZ, Response: {'nombres': 'NARCISO', 'primer_apellido': 'BERBERANA', 'segundo_apellido': 'SAENZ'}
# Nombre: JORGE MANENT CODINA, Response: {'nombres': 'JORGE MANENT', 'primer_apellido': 'CODINA', 'segundo_apellido': ''}
# Nombre: FERNANDO SAMANIEGO SANGRONIZ, Response: {'nombres': 'FERNANDO', 'primer_apellido': 'SAMANIEGO', 'segundo_apellido': 'SANGRONIZ'}
# Nombre: PEDRO SIERRA BOSCH, Response: {'nombres': 'PEDRO', 'primer_apellido': 'SIERRA', 'segundo_apellido': 'BOSCH'}
# Nombre: RICARDO ESCOBAR CALDERON, Response: {'nombres': 'RICARDO', 'primer_apellido': 'ESCOBAR', 'segundo_apellido': 'CALDERON'}
# Nombre: LAUREANO CANO INIESTA, Response: {'nombres': 'LAUREANO', 'primer_apellido': 'CANO', 'segundo_apellido': 'INIESTA'}
# Nombre: BRUNO PHILIPPI IRARRAZABAL, Response: {'nombres': 'BRUNO PHILIPPI', 'primer_apellido': 'IRARRAZABAL', 'segundo_apellido': ''}
# Nombre: NICOLE NHEME ZALAQUET, Response: {'nombres': 'NICOLE', 'primer_apellido': 'NHEME', 'segundo_apellido': 'ZALAQUET'}
# Nombre: GONZALO ROJAS VILDOSOLA, Response: {'nombres': 'Gonzalo', 'primer_apellido': 'Rojas', 'segundo_apellido': 'Vildosola'}
# Nombre: LUIS HERNAN PAUL FRESNO, Response: {'nombres': 'LUIS HERNAN PAUL', 'primer_apellido': 'FRESNO', 'segundo_apellido': ''}
# Nombre: XAVIER AMOROS CORBELLA, Response: {'nombres': 'XAVIER AMOROS', 'primer_apellido': 'CORBELLA', 'segundo_apellido': ''}
# Nombre: MARIO PUENTES LACAMARA, Response: {'nombres': 'MARIO', 'primer_apellido': 'PUENTES', 'segundo_apellido': 'LACAMARA'}
# Nombre: SERGIO GUZMAN LAGOS, Response: {'nombres': 'SERGIO', 'primer_apellido': 'GUZMAN', 'segundo_apellido': 'LAGOS'}
# Nombre: ARTURO VERGARA DEL RIO, Response: {'nombres': 'ARTURO', 'primer_apellido': 'VERGARA', 'segundo_apellido': 'DEL RIO'}
# Nombre: RICARDO SANHUEZA PALMA, Response: {'nombres': 'RICARDO', 'primer_apellido': 'SANHUEZA', 'segundo_apellido': 'PALMA'}
# Nombre: MAURICIO ROJAS MULLOR, Response: {'nombres': 'MAURICIO', 'primer_apellido': 'ROJAS', 'segundo_apellido': 'MULLOR'}
# Nombre: SONIA LEONOR TSCHORNE BERESTESKY, Response: {'nombres': 'SONIA LEONOR', 'primer_apellido': 'TSCHORNE', 'segundo_apellido': 'BERESTESKY'}
# Nombre: TOMAS UAUY CUNEO, Response: {'nombres': 'TOMAS', 'primer_apellido': 'UAUY', 'segundo_apellido': 'CUNEO'}
# Nombre: COSME SAGNIER GUIMON, Response: {'nombres': 'COSME', 'primer_apellido': 'SAGNIER', 'segundo_apellido': 'GUIMON'}
# Nombre: RODRIGO TERRE FONTBONA, Response: {'nombres': 'RODRIGO TERRE', 'primer_apellido': 'FONTBONA', 'segundo_apellido': ''}
# Nombre: CHRISTOPHE CROS O, Response: {'nombres': 'CHRISTOPHE', 'primer_apellido': 'CROS', 'segundo_apellido': 'O'}
# Nombre: CHRISTOPHE CROS 0, Response: {'nombres': 'CHRISTOPHE', 'primer_apellido': 'CROS', 'segundo_apellido': ''}
# Nombre: JAIME CUEVAS RODRIGUEZ, Response: {'nombres': 'JAIME', 'primer_apellido': 'CUEVAS', 'segundo_apellido': 'RODRIGUEZ'}
# Nombre: JORGE COSME SAGNIER GUIMON, Response: {'nombres': 'JORGE COSME', 'primer_apellido': 'SAGNIER', 'segundo_apellido': 'GUIMON'}
# Nombre: OLIVER JAQUIER N, Response: {'nombres': 'OLIVER JAQUIER', 'primer_apellido': 'N', 'segundo_apellido': ''}
# Nombre: LORENZO BERNALDO DE QUIROZ LOZANO, Response: {'nombres': 'LORENZO', 'primer_apellido': 'BERNALDO DE QUIROZ', 'segundo_apellido': 'LOZANO'}
# Nombre: ALEJANDRO DANUS CHIRIGHIN, Response: {'nombres': 'ALEJANDRO DANUS', 'primer_apellido': 'CHIRIGHIN', 'segundo_apellido': ''}
# Nombre: PIERRE ALEXANDER LACARELLE, Response: {'nombres': 'PIERRE ALEXANDER', 'primer_apellido': 'LACARELLE', 'segundo_apellido': ''}
# Nombre: ERNESTO MATA LOPEZ, Response: {'nombres': 'ERNESTO', 'primer_apellido': 'MATA', 'segundo_apellido': 'LOPEZ'}
# Nombre: LORENZO BERNALDO DE QUIROS, Response: {'nombres': 'LORENZO', 'primer_apellido': 'BERNALDO', 'segundo_apellido': 'DE QUIROS'}
# Nombre: VICTOR HUGO SELMAN BIESTER, Response: {'nombres': 'VICTOR HUGO', 'primer_apellido': 'SELMAN', 'segundo_apellido': 'BIESTER'}
# Nombre: LUIS ANDRES RENGIFO BRICENO, Response: {'nombres': 'LUIS ANDRES', 'primer_apellido': 'RENGIFO', 'segundo_apellido': 'BRICENO'}
# Nombre: JUAN ANTONIO FIGUEROA , Response: {'nombres': 'JUAN ANTONIO', 'primer_apellido': 'FIGUEROA', 'segundo_apellido': ''}
# Nombre: SALVADOR VILLARINO KRUMM, Response: {'nombres': 'SALVADOR', 'primer_apellido': 'VILLARINO', 'segundo_apellido': 'KRUMM'}
# Nombre: DIANE DARRAS , Response: {'nombres': 'DIANE', 'primer_apellido': 'DARRAS', 'segundo_apellido': ''}
# Nombre: ANTONI SIURANA ZARAGOZA, Response: {'nombres': 'ANTONI', 'primer_apellido': 'SIURANA', 'segundo_apellido': 'ZARAGOZA'}
# Nombre: JUAN ANTONIO GUIJARRO FERRER, Response: {'nombres': 'JUAN ANTONIO', 'primer_apellido': 'GUIJARRO', 'segundo_apellido': 'FERRER'}
# Nombre: SARA VERONICA SMOK UBEDA, Response: {'nombres': 'SARA VERONICA', 'primer_apellido': 'SMOK', 'segundo_apellido': 'UBEDA'}
# Nombre: CESAR JORGE BARROS MONTERO, Response: {'nombres': 'CESAR JORGE', 'primer_apellido': 'BARROS', 'segundo_apellido': 'MONTERO'}
# Nombre: ANTONIO CASTILLA PEREZ, Response: {'nombres': 'ANTONIO', 'primer_apellido': 'CASTILLA', 'segundo_apellido': 'PEREZ'}
# Nombre: JOSEFINA MONTENEGRO ARANEDA, Response: {'nombres': 'JOSEFINA', 'primer_apellido': 'MONTENEGRO', 'segundo_apellido': 'ARANEDA'}
# Nombre: JAIME MORENO ZANNI, Response: {'nombres': 'JAIME', 'primer_apellido': 'MORENO', 'segundo_apellido': 'ZANNI'}
# Nombre: JORGE ARTURO AGUAYO RIOS, Response: {'nombres': 'JORGE ARTURO', 'primer_apellido': 'AGUAYO', 'segundo_apellido': 'RIOS'}
# Nombre: VERONICA PEREZ WEINSTEIN, Response: {'nombres': 'VERONICA', 'primer_apellido': 'PEREZ', 'segundo_apellido': 'WEINSTEIN'}
# Nombre: RAUL CARLOS RIQUELME PEREZ, Response: {'nombres': 'RAUL CARLOS', 'primer_apellido': 'RIQUELME', 'segundo_apellido': 'PEREZ'}
# Nombre: CRISTIAN ABBOTT ALCALDE, Response: {'nombres': 'CRISTIAN', 'primer_apellido': 'ABBOTT', 'segundo_apellido': 'ALCALDE'}
# Nombre: LILIAN ANDREA SANHUEZA SANHUEZA, Response: {'nombres': 'LILIAN ANDREA', 'primer_apellido': 'SANHUEZA', 'segundo_apellido': 'SANHUEZA'}
# Nombre: PEDRO GUTIERREZ DIAZ, Response: {'nombres': 'PEDRO', 'primer_apellido': 'GUTIERREZ', 'segundo_apellido': 'DIAZ'}
# Nombre: GLORIA PAULINA CUADRA MINO, Response: {'nombres': 'GLORIA PAULINA', 'primer_apellido': 'CUADRA', 'segundo_apellido': 'MINO'}
# Nombre: MARIA SOLEDAD ARELLANO SCHIMDT, Response: {'nombres': 'MARIA SOLEDAD', 'primer_apellido': 'ARELLANO', 'segundo_apellido': 'SCHIMDT'}
# Nombre: CLAUDIO SOLER CORTINA, Response: {'nombres': 'CLAUDIO SOLER', 'primer_apellido': 'CORTINA', 'segundo_apellido': ''}
# Nombre: VERONICA GONZALEZ GIL, Response: {'nombres': 'VERONICA', 'primer_apellido': 'GONZALEZ', 'segundo_apellido': 'GIL'}
# Nombre: JUAN MORENO GAMBOA, Response: {'nombres': 'JUAN', 'primer_apellido': 'MORENO', 'segundo_apellido': 'GAMBOA'}
# Nombre: MANUEL LOPEZ MARIN, Response: {'nombres': 'MANUEL', 'primer_apellido': 'LOPEZ', 'segundo_apellido': 'MARIN'}
# Nombre: LUIS ROJAS ALFARO, Response: {'nombres': 'LUIS', 'primer_apellido': 'ROJAS', 'segundo_apellido': 'ALFARO'}
# Nombre: VICTOR PEREZ MUNOZ, Response: {'nombres': 'VICTOR', 'primer_apellido': 'PEREZ', 'segundo_apellido': 'MUNOZ'}
# Nombre: ALFREDO WALTER KUNZE SCHUTZE, Response: {'nombres': 'ALFREDO WALTER', 'primer_apellido': 'KUNZE', 'segundo_apellido': 'SCHUTZE'}
# Nombre: ENZO ANDRES VALLARINO ESTAY, Response: {'nombres': 'ENZO ANDRES', 'primer_apellido': 'VALLARINO', 'segundo_apellido': 'ESTAY'}
# Nombre: GABRIEL ATILANO RIVEROS INFANTE, Response: {'nombres': 'GABRIEL ATILANO', 'primer_apellido': 'RIVEROS', 'segundo_apellido': 'INFANTE'}
# Nombre: JOSE ARTURO LYON PAROT, Response: {'nombres': 'JOSE ARTURO', 'primer_apellido': 'LYON', 'segundo_apellido': 'PAROT'}
# Nombre: GASTON LEWIN GOMEZ, Response: {'nombres': 'GASTON LEWIN', 'primer_apellido': 'GOMEZ', 'segundo_apellido': ''}
# Nombre: ENRIQUE MARCELO OYARCE CIFUENTES, Response: {'nombres': 'ENRIQUE MARCELO', 'primer_apellido': 'OYARCE', 'segundo_apellido': 'CIFUENTES'}
# Nombre: VICTOR MANUEL RIVEROS CONTRERAS, Response: {'nombres': 'VICTOR MANUEL', 'primer_apellido': 'RIVEROS', 'segundo_apellido': 'CONTRERAS'}
# Nombre: MARCELO ENRIQUE SOLIS HERNANDEZ, Response: {'nombres': 'MARCELO ENRIQUE', 'primer_apellido': 'SOLIS', 'segundo_apellido': 'HERNANDEZ'}
# Nombre: ANTONIO BASCUNAN VALDES, Response: {'nombres': 'ANTONIO', 'primer_apellido': 'BASCUNAN', 'segundo_apellido': 'VALDES'}
# Nombre: ARTURO GENARO FAUNDEZ FUENTES, Response: {'nombres': 'ARTURO GENARO', 'primer_apellido': 'FAUNDEZ', 'segundo_apellido': 'FUENTES'}
# Nombre: IVAN URZUA AHUMADA, Response: {'nombres': 'IVAN', 'primer_apellido': 'URZUA', 'segundo_apellido': 'AHUMADA'}
# Nombre: EDUARDO FREDY NUNEZ CAMPOS, Response: {'nombres': 'EDUARDO FREDY', 'primer_apellido': 'NUNEZ', 'segundo_apellido': 'CAMPOS'}
# Nombre: VLADIMIR ANTONIO SCIARAFFIA VALENZUELA, Response: {'nombres': 'VLADIMIR ANTONIO', 'primer_apellido': 'SCIARAFFIA', 'segundo_apellido': 'VALENZUELA'}
# Nombre: JULIO RUIZ FERNANDEZ, Response: {'nombres': 'JULIO', 'primer_apellido': 'RUIZ', 'segundo_apellido': 'FERNANDEZ'}
# Nombre: PATRICIO FERNANDO SESNICH STEWART, Response: {'nombres': 'PATRICIO FERNANDO', 'primer_apellido': 'SESNICH', 'segundo_apellido': 'STEWART'}
# Nombre: LUIS ALBERTO SIMIAN DIAZ, Response: {'nombres': 'LUIS ALBERTO', 'primer_apellido': 'SIMIAN', 'segundo_apellido': 'DIAZ'}
# Nombre: PAOLA BRUZZONE GOLDSMITH, Response: {'nombres': 'PAOLA', 'primer_apellido': 'BRUZZONE', 'segundo_apellido': 'GOLDSMITH'}
# Nombre: PERLA VERONICA URIBE RIVAS, Response: {'nombres': 'PERLA VERONICA', 'primer_apellido': 'URIBE', 'segundo_apellido': 'RIVAS'}
# Nombre: CARMEN ADRIANA DELPIANO PUELMA, Response: {'nombres': 'CARMEN ADRIANA', 'primer_apellido': 'DELPIANO', 'segundo_apellido': 'PUELMA'}
# Nombre: SAMUEL EDUARDO PUENTES LACAMARA, Response: {'nombres': 'SAMUEL EDUARDO', 'primer_apellido': 'PUENTES', 'segundo_apellido': 'LACAMARA'}
# Nombre: RAUL MANFREDO ARONSOHN FALICKMANN, Response: {'nombres': 'RAUL MANFREDO', 'primer_apellido': 'ARONSOHN', 'segundo_apellido': 'FALICKMANN'}
# Nombre: MARIE PAULE ITHURBISQUY LAPORTE, Response: {'nombres': 'MARIE PAULE', 'primer_apellido': 'ITHURBISQUY', 'segundo_apellido': 'LAPORTE'}
# Nombre: GONZALO FERNANDO DE URRUTICOECHEA SARTORIUS, Response: {'nombres': 'GONZALO FERNANDO', 'primer_apellido': 'DE URRUTICOECHEA', 'segundo_apellido': 'SARTORIUS'}
# Nombre: ROXANA CERDA NORAMBUENA, Response: {'nombres': 'ROXANA', 'primer_apellido': 'CERDA', 'segundo_apellido': 'NORAMBUENA'}
# Nombre: RAIMUNDO CRUZAT CORREA, Response: {'nombres': 'RAIMUNDO', 'primer_apellido': 'CRUZAT', 'segundo_apellido': 'CORREA'}
# Nombre: MATIAS ACEVEDO FERRER, Response: {'nombres': 'MATIAS', 'primer_apellido': 'ACEVEDO', 'segundo_apellido': 'FERRER'}
# Nombre: ADRIANA ALICIA TAPIA CIFUENTES, Response: {'nombres': 'ADRIANA ALICIA', 'primer_apellido': 'TAPIA', 'segundo_apellido': 'CIFUENTES'}
# Nombre: FELIPE AGUSTIN TOMAS PEREZ WALKER, Response: {'nombres': 'FELIPE AGUSTIN TOMAS', 'primer_apellido': 'PEREZ', 'segundo_apellido': 'WALKER'}
# Nombre: PATRICIO ARMANDO DUSSAILLANT BALBONTIN, Response: {'nombres': 'PATRICIO ARMANDO', 'primer_apellido': 'DUSSAILLANT', 'segundo_apellido': 'BALBONTIN'}
# Nombre: JUAN CARLOS TOLEDO NINO DE ZEPEDA, Response: {'nombres': 'JUAN CARLOS', 'primer_apellido': 'TOLEDO', 'segundo_apellido': 'NINO DE ZEPEDA'}
# Nombre: MARIA ANTONIETA ESTAY MONTENEGRO, Response: {'nombres': 'MARIA ANTONIETA', 'primer_apellido': 'ESTAY', 'segundo_apellido': 'MONTENEGRO'}
# Nombre: MARIA MAGDALENA BALCELLS GONZALEZ, Response: {'nombres': 'MARIA MAGDALENA', 'primer_apellido': 'BALCELLS', 'segundo_apellido': 'GONZALEZ'}
# Nombre: MARIA JOSEFINA GUZMAN BILBAO, Response: {'nombres': 'MARIA JOSEFINA', 'primer_apellido': 'GUZMAN', 'segundo_apellido': 'BILBAO'}
# Nombre: GABRIELA ALEJANDRA KRAUSS VALLE, Response: {'nombres': 'GABRIELA ALEJANDRA', 'primer_apellido': 'KRAUSS', 'segundo_apellido': 'VALLE'}
# Nombre: BENJAMIN HOLMES BIERWIRTH, Response: {'nombres': 'BENJAMIN HOLMES', 'primer_apellido': 'BIERWIRTH', 'segundo_apellido': ''}
# Nombre: GIORGIO ESTEBAN ALFREDO MACCHIAVELLO YURAS, Response: {'nombres': 'GIORGIO ESTEBAN ALFREDO', 'primer_apellido': 'MACCHIAVELLO', 'segundo_apellido': 'YURAS'}
# Nombre: GERARDO MARTIN UNA , Response: {'nombres': 'GERARDO MARTIN', 'primer_apellido': 'UNA', 'segundo_apellido': ''}
# Nombre: EUGENIO ERNESTO HIDALGO GONZALEZ, Response: {'nombres': 'EUGENIO ERNESTO', 'primer_apellido': 'HIDALGO', 'segundo_apellido': 'GONZALEZ'}
# Nombre: CLAUDIA IVONNE ROJAS CAMPOS, Response: {'nombres': 'CLAUDIA IVONNE', 'primer_apellido': 'ROJAS', 'segundo_apellido': 'CAMPOS'}
# Nombre: ENRIQUE VALDIVIESO VALDES, Response: {'nombres': 'ENRIQUE', 'primer_apellido': 'VALDIVIESO', 'segundo_apellido': 'VALDES'}
# Nombre: IGNACIO BRIONES ROJAS, Response: {'nombres': 'IGNACIO', 'primer_apellido': 'BRIONES', 'segundo_apellido': 'ROJAS'}
# Nombre: MIGUEL CARLOS BEJIDE CATRILEO, Response: {'nombres': 'MIGUEL CARLOS', 'primer_apellido': 'BEJIDE', 'segundo_apellido': 'CATRILEO'}
# Nombre: CRISTIAN MARDONES PANTOJA, Response: {'nombres': 'CRISTIAN', 'primer_apellido': 'MARDONES', 'segundo_apellido': 'PANTOJA'}
# Nombre: WALDO MANUEL MORA LONGA, Response: {'nombres': 'WALDO MANUEL', 'primer_apellido': 'MORA', 'segundo_apellido': 'LONGA'}
# Nombre: JORGE ADOLFO LESSER GARCIAHUIDOBRO, Response: {'nombres': 'JORGE ADOLFO', 'primer_apellido': 'LESSER', 'segundo_apellido': 'GARCIAHUIDOBRO'}
# Nombre: JUAN IGNACIO PAROT BECKER, Response: {'nombres': 'JUAN IGNACIO', 'primer_apellido': 'PAROT', 'segundo_apellido': 'BECKER'}
# Nombre: JUAN PABLO ARMAS MAC DONALD, Response: {'nombres': 'JUAN PABLO', 'primer_apellido': 'ARMAS', 'segundo_apellido': 'MAC DONALD'}
# Nombre: ALEJANDRO FERREIRO YAZIGI, Response: {'nombres': 'ALEJANDRO', 'primer_apellido': 'FERREIRO', 'segundo_apellido': 'YAZIGI'}
# Nombre: STACEY PURCELL , Response: {'nombres': 'STACEY', 'primer_apellido': 'PURCELL', 'segundo_apellido': ''}
# Nombre: MICHAEL NIGGLI , Response: {'nombres': 'MICHAEL', 'primer_apellido': 'NIGGLI', 'segundo_apellido': ''}
# Nombre: OLGA BOTERO , Response: {'nombres': 'OLGA', 'primer_apellido': 'BOTERO', 'segundo_apellido': ''}
# Nombre: STEPHEN BEST , Response: {'nombres': 'STEPHEN', 'primer_apellido': 'BEST', 'segundo_apellido': ''}
# Nombre: JOHN ELLIOT KAYE, Response: {'nombres': 'JOHN ELLIOT', 'primer_apellido': 'KAYE', 'segundo_apellido': ''}
# Nombre: JOHN KAYE , Response: {'nombres': 'JOHN', 'primer_apellido': 'KAYE', 'segundo_apellido': ''}
# Nombre: BARBARA ZVAN, Response: {'nombres': 'BARBARA', 'primer_apellido': 'ZVAN', 'segundo_apellido': ''}
# Nombre: WILLIAMS DALE BURGUESS, Response: {'nombres': 'WILLIAMS DALE', 'primer_apellido': 'BURGUESS', 'segundo_apellido': ''}
# Nombre: MICHAEL R NIGGLI , Response: {'nombres': 'MICHAEL R', 'primer_apellido': 'NIGGLI', 'segundo_apellido': ''}
# Nombre: JOHN ELLIOT KAYE , Response: {'nombres': 'JOHN ELLIOT', 'primer_apellido': 'KAYE', 'segundo_apellido': ''}
# Nombre: MARIA IGNACIA BENITEZ PEREIRA, Response: {'nombres': 'MARIA IGNACIA', 'primer_apellido': 'BENITEZ', 'segundo_apellido': 'PEREIRA'}
# Nombre: JOHN ELLIOTT KAYE , Response: {'nombres': 'JOHN ELLIOTT', 'primer_apellido': 'KAYE', 'segundo_apellido': ''}
# Nombre: STACEY PURCELL, Response: {'nombres': 'STACEY', 'primer_apellido': 'PURCELL', 'segundo_apellido': ''}
# Nombre: WILLIAM DALE BURGESS , Response: {'nombres': 'WILLIAM DALE', 'primer_apellido': 'BURGESS', 'segundo_apellido': ''}
# Nombre: OLIVIA PENELOPE STEEDMAN , Response: {'nombres': 'OLIVIA PENELOPE', 'primer_apellido': 'STEEDMAN', 'segundo_apellido': ''}
# Nombre: STACEY LEANNE PURCELL , Response: {'nombres': 'STACEY LEANNE', 'primer_apellido': 'PURCELL', 'segundo_apellido': ''}
# Nombre: JUAN GUILLERMO SABATER MAROTO, Response: {'nombres': 'JUAN GUILLERMO', 'primer_apellido': 'SABATER', 'segundo_apellido': 'MAROTO'}
# Nombre: OSCAR VON CHRISMAR CARVAJAL, Response: {'nombres': 'OSCAR VON CHRISMAR', 'primer_apellido': 'CARVAJAL', 'segundo_apellido': ''}
# Nombre: MIGUEL MATA HUERTA, Response: {'nombres': 'MIGUEL', 'primer_apellido': 'MATA', 'segundo_apellido': 'HUERTA'}
# Nombre: SERGIO AVILA SALAS, Response: {'nombres': 'SERGIO', 'primer_apellido': 'AVILA', 'segundo_apellido': 'SALAS'}
# Nombre: MATIAS SANCHEZ GARCIA, Response: {'nombres': 'MATIAS', 'primer_apellido': 'SANCHEZ', 'segundo_apellido': 'GARCIA'}
# Nombre: FRANCO RIZZA , Response: {'nombres': 'FRANCO', 'primer_apellido': 'RIZZA', 'segundo_apellido': ''}
# Nombre: JUAN PABLO ABOITIZ DOMINGUEZ, Response: {'nombres': 'JUAN PABLO', 'primer_apellido': 'ABOITIZ', 'segundo_apellido': 'DOMINGUEZ'}
# Nombre: GONZALO ENRIQUE CAVADA CHARLES, Response: {'nombres': 'GONZALO ENRIQUE', 'primer_apellido': 'CAVADA', 'segundo_apellido': 'CHARLES'}
# Nombre: IGNACIO ENCISO MERINO, Response: {'nombres': 'IGNACIO', 'primer_apellido': 'ENCISO', 'segundo_apellido': 'MERINO'}
# Nombre: RAFAEL SAINZ DE HERRERA, Response: {'nombres': 'RAFAEL', 'primer_apellido': 'SAINZ DE', 'segundo_apellido': 'HERRERA'}
# Nombre: CRISTIAN FLORENCE KAUER, Response: {'nombres': 'CRISTIAN FLORENCE', 'primer_apellido': 'KAUER', 'segundo_apellido': ''}
# Nombre: ANTONIO GORORDO ALCALDE, Response: {'nombres': 'ANTONIO', 'primer_apellido': 'GORORDO', 'segundo_apellido': 'ALCALDE'}
# Nombre: FRANCISCO ERRAZURIZ DOMINGUEZ, Response: {'nombres': 'FRANCISCO', 'primer_apellido': 'ERRAZURIZ', 'segundo_apellido': 'DOMINGUEZ'}
# Nombre: JUAN PEDRO SANTA MARIA PEREZ, Response: {'nombres': 'JUAN PEDRO', 'primer_apellido': 'SANTA MARIA', 'segundo_apellido': 'PEREZ'}
# Nombre: BANCO SANTANDER CHILE, Response: {'nombres': 'BANCO SANTANDER', 'primer_apellido': 'CHILE', 'segundo_apellido': ''}
# Nombre: 0 0 0, Response: {'nombres': '0', 'primer_apellido': '0', 'segundo_apellido': '0'}
# Nombre: SIMON BLAIR , Response: {'nombres': 'SIMON', 'primer_apellido': 'BLAIR', 'segundo_apellido': ''}
# Nombre: IGNACIO ERENO IRIBARREN, Response: {'nombres': 'IGNACIO', 'primer_apellido': 'ERENO', 'segundo_apellido': 'IRIBARREN'}
# Nombre: SALVADOR SAID SOMAVIA, Response: {'nombres': 'SALVADOR SAID', 'primer_apellido': 'SOMAVIA', 'segundo_apellido': ''}
# Nombre: FERNANDO GARCIA LAZARO, Response: {'nombres': 'FERNANDO', 'primer_apellido': 'GARCIA', 'segundo_apellido': 'LAZARO'}
# Nombre: CARLOS ANTONIO JAUREGUIZAR RUIZ  JARABO, Response: {'nombres': 'CARLOS ANTONIO', 'primer_apellido': 'JAUREGUIZAR', 'segundo_apellido': 'RUIZ JARABO'}
# Nombre: JOSE RAMON ALVAREZ  RENDUELES MEDINA, Response: {'nombres': 'JOSE RAMON', 'primer_apellido': 'ALVAREZ RENDUELES', 'segundo_apellido': 'MEDINA'}
# Nombre: MONICA PARAMES GARCIA  ASTIGARRAGA, Response: {'nombres': 'MONICA', 'primer_apellido': 'PARAMES GARCIA', 'segundo_apellido': 'ASTIGARRAGA'}
# Nombre: RAFAEL PRADO GONZALEZ, Response: {'nombres': 'RAFAEL', 'primer_apellido': 'PRADO', 'segundo_apellido': 'GONZALEZ'}
# Nombre: JOHN EDWARD TOOKE , Response: {'nombres': 'JOHN EDWARD', 'primer_apellido': 'TOOKE', 'segundo_apellido': ''}
# Nombre: ALVARO ERAZO LATORRE, Response: {'nombres': 'ALVARO', 'primer_apellido': 'ERAZO', 'segundo_apellido': 'LATORRE'}
# Nombre: CARLOS JAUREGUIZAR RUIZJARABO, Response: {'nombres': 'CARLOS', 'primer_apellido': 'JAUREGUIZAR', 'segundo_apellido': 'RUIZJARABO'}
# Nombre: MONICA PARAMES GARCIAASTIGARRAGA, Response: {'nombres': 'MONICA', 'primer_apellido': 'PARAMES', 'segundo_apellido': 'GARCIAASTIGARRAGA'}
# Nombre: ANDRES VARAS GREENE, Response: {'nombres': 'ANDRES', 'primer_apellido': 'VARAS', 'segundo_apellido': 'GREENE'}
# Nombre: JORGE ARTURO BANDE BRUCK, Response: {'nombres': 'JORGE ARTURO', 'primer_apellido': 'BANDE', 'segundo_apellido': 'BRUCK'}
# Nombre: JOSE FRANCISCO TOMAS MARTINEZ, Response: {'nombres': 'JOSE FRANCISCO TOMAS', 'primer_apellido': 'MARTINEZ', 'segundo_apellido': ''}
# Nombre: GABRIELA PUEYO ROBERTS, Response: {'nombres': 'GABRIELA', 'primer_apellido': 'PUEYO', 'segundo_apellido': 'ROBERTS'}
# Nombre: RODRIGO MUNOZ MUNOZ, Response: {'nombres': 'RODRIGO', 'primer_apellido': 'MUNOZ', 'segundo_apellido': 'MUNOZ'}
# Nombre: ALVARO SALOMON FISCHER ABELIUK, Response: {'nombres': 'ALVARO SALOMON', 'primer_apellido': 'FISCHER', 'segundo_apellido': 'ABELIUK'}
# Nombre: MARCOS BUCHI BUC, Response: {'nombres': 'MARCOS', 'primer_apellido': 'BUCHI', 'segundo_apellido': 'BUC'}
# Nombre: PABLO WAGNER SAN MARTIN, Response: {'nombres': 'PABLO', 'primer_apellido': 'WAGNER', 'segundo_apellido': 'SAN MARTIN'}
# Nombre: FELIPE LARRAIN TEJEDA, Response: {'nombres': 'FELIPE', 'primer_apellido': 'LARRAIN', 'segundo_apellido': 'TEJEDA'}
# Nombre: CARLOS G INGHAM KOTTMEIER, Response: {'nombres': 'CARLOS G', 'primer_apellido': 'INGHAM', 'segundo_apellido': 'KOTTMEIER'}
# Nombre: TIMOTHY CONGER PURCELL , Response: {'nombres': 'TIMOTHY CONGER', 'primer_apellido': 'PURCELL', 'segundo_apellido': ''}
# Nombre: FERNANDO JOSE ECHEVERRIA VIAL, Response: {'nombres': 'FERNANDO JOSE', 'primer_apellido': 'ECHEVERRIA', 'segundo_apellido': 'VIAL'}
# Nombre: DARIO ARTURO BARROS RAMIREZ, Response: {'nombres': 'DARIO ARTURO', 'primer_apellido': 'BARROS', 'segundo_apellido': 'RAMIREZ'}
# Nombre: MARCELO AWAD AWAD, Response: {'nombres': 'MARCELO', 'primer_apellido': 'AWAD', 'segundo_apellido': 'AWAD'}
# Nombre: BERNARDO ALBERTO ECHEVERRIA VIAL, Response: {'nombres': 'BERNARDO ALBERTO', 'primer_apellido': 'ECHEVERRIA', 'segundo_apellido': 'VIAL'}
# Nombre: ALVARO GABRIEL IZQUIERDO WACHHOLTZ, Response: {'nombres': 'ALVARO GABRIEL', 'primer_apellido': 'IZQUIERDO', 'segundo_apellido': 'WACHHOLTZ'}
# Nombre: FRANCISCO RAMON GUTIERREZ PHILIPPI, Response: {'nombres': 'FRANCISCO RAMON', 'primer_apellido': 'GUTIERREZ', 'segundo_apellido': 'PHILIPPI'}
# Nombre: ANDREA ISABEL REPETTO LISBOA, Response: {'nombres': 'ANDREA ISABEL', 'primer_apellido': 'REPETTO', 'segundo_apellido': 'LISBOA'}
# Nombre: PABLO IHNEN DE LA FUENTE, Response: {'nombres': 'PABLO IHNEN', 'primer_apellido': 'DE LA FUENTE', 'segundo_apellido': ''}
# Nombre: GONZALO ERRAZURIZ HERRERA, Response: {'nombres': 'Gonzalo', 'primer_apellido': 'Errazuriz', 'segundo_apellido': 'Herrera'}
# Nombre: RICARDO LEVY GUARDA, Response: {'nombres': 'RICARDO', 'primer_apellido': 'LEVY', 'segundo_apellido': 'GUARDA'}
# Nombre: FERNANDO DEL SOL GUZMAN, Response: {'nombres': 'FERNANDO DEL SOL', 'primer_apellido': 'GUZMAN', 'segundo_apellido': ''}
# Nombre: HORACIO NOLBERTO PAVEZ GARCIA, Response: {'nombres': 'HORACIO NOLBERTO', 'primer_apellido': 'PAVEZ', 'segundo_apellido': 'GARCIA'}
# Nombre: ALEJANDRO ALBERTZ KLEIN, Response: {'nombres': 'ALEJANDRO', 'primer_apellido': 'ALBERTZ', 'segundo_apellido': 'KLEIN'}
# Nombre: MARCO COMPARINI FONTECILLA, Response: {'nombres': 'MARCO', 'primer_apellido': 'COMPARINI', 'segundo_apellido': 'FONTECILLA'}
# Nombre: FELIPE BERTIN PUGA, Response: {'nombres': 'FELIPE BERTIN', 'primer_apellido': 'PUGA', 'segundo_apellido': ''}
# Nombre: ALEJANDRO ANDRES ARRAU DE LA SOTTA, Response: {'nombres': 'ALEJANDRO ANDRES', 'primer_apellido': 'ARRAU', 'segundo_apellido': 'DE LA SOTTA'}
# Nombre: FERNANDO JOSE TISNE MARITANO, Response: {'nombres': 'FERNANDO JOSE', 'primer_apellido': 'TISNE', 'segundo_apellido': 'MARITANO'}
# Nombre: JUAN LEON BABAROVIC, Response: {'nombres': 'JUAN LEON', 'primer_apellido': 'BABAROVIC', 'segundo_apellido': ''}
# Nombre: IGNACIO LLANOS VIDAL, Response: {'nombres': 'IGNACIO', 'primer_apellido': 'LLANOS', 'segundo_apellido': 'VIDAL'}
# Nombre: FERNANDO FRANKE GARCIA, Response: {'nombres': 'FERNANDO', 'primer_apellido': 'FRANKE', 'segundo_apellido': 'GARCIA'}
# Nombre: EDUARDO GUERRERO NUNEZ, Response: {'nombres': 'EDUARDO', 'primer_apellido': 'GUERRERO', 'segundo_apellido': 'NUNEZ'}
# Nombre: RODRIGO GONZALEZ GONZALEZ, Response: {'nombres': 'RODRIGO', 'primer_apellido': 'GONZALEZ', 'segundo_apellido': 'GONZALEZ'}
# Nombre: OCTAVIO BOFILL GENZSCH, Response: {'nombres': 'OCTAVIO', 'primer_apellido': 'BOFILL', 'segundo_apellido': 'GENZSCH'}
# Nombre: ANA MARIA YURI CASTELLON, Response: {'nombres': 'ANA MARIA YURI', 'primer_apellido': 'CASTELLON', 'segundo_apellido': ''}
# Nombre: FERNANDO DEL SOL SANTA CRUZ, Response: {'nombres': 'FERNANDO DEL SOL', 'primer_apellido': 'SANTA CRUZ', 'segundo_apellido': ''}
# Nombre: ANTONIO GIL NIEVAS, Response: {'nombres': 'ANTONIO', 'primer_apellido': 'GIL', 'segundo_apellido': 'NIEVAS'}
# Nombre: RAUL SCHMIDT HUTCHISON, Response: {'nombres': 'RAUL', 'primer_apellido': 'SCHMIDT', 'segundo_apellido': 'HUTCHISON'}
# Nombre: PEDRO RUIZCLAVIJO GARCIA, Response: {'nombres': 'PEDRO', 'primer_apellido': 'RUIZCLAVIJO', 'segundo_apellido': 'GARCIA'}
# Nombre: SEBASTIAN REY LIZZANO, Response: {'nombres': 'SEBASTIAN', 'primer_apellido': 'REY', 'segundo_apellido': 'LIZZANO'}
# Nombre: MARIA ANA MATTHIAS CAMPOS, Response: {'nombres': 'MARIA ANA', 'primer_apellido': 'MATTHIAS', 'segundo_apellido': 'CAMPOS'}
# Nombre: ROBERT JM ROGGEN , Response: {'nombres': 'ROBERT JM', 'primer_apellido': 'ROGGEN', 'segundo_apellido': ''}
# Nombre: EDUARDO VALENCIA SEPULVEDA, Response: {'nombres': 'EDUARDO', 'primer_apellido': 'VALENCIA', 'segundo_apellido': 'SEPULVEDA'}
# Nombre: CAROLINA ELIZABETH ROSSI , Response: {'nombres': 'CAROLINA ELIZABETH', 'primer_apellido': 'ROSSI', 'segundo_apellido': ''}
# Nombre: LARA PEREIRA , Response: {'nombres': 'LARA', 'primer_apellido': 'PEREIRA', 'segundo_apellido': ''}
# Nombre: YANINA MANASSA CONTRERAS, Response: {'nombres': 'YANINA', 'primer_apellido': 'MANASSA', 'segundo_apellido': 'CONTRERAS'}
# Nombre: ANA MARIA LAMONICA ALONSO, Response: {'nombres': 'ANA MARIA', 'primer_apellido': 'LAMONICA', 'segundo_apellido': 'ALONSO'}
# Nombre: LORENA CAMPOS TRAVISANY, Response: {'nombres': 'LORENA', 'primer_apellido': 'CAMPOS', 'segundo_apellido': 'TRAVISANY'}
# Nombre: MARIA VICTORIA ROJAS MATUTE, Response: {'nombres': 'MARIA VICTORIA', 'primer_apellido': 'ROJAS', 'segundo_apellido': 'MATUTE'}
# Nombre: CAROLA ERLBAUM PALMA, Response: {'nombres': 'CAROLA', 'primer_apellido': 'ERLBAUM', 'segundo_apellido': 'PALMA'}
# Nombre: NICOLAS GRASSI , Response: {'nombres': 'NICOLAS', 'primer_apellido': 'GRASSI', 'segundo_apellido': ''}
# Nombre: TIAGO RIVERA JARA, Response: {'nombres': 'TIAGO', 'primer_apellido': 'RIVERA', 'segundo_apellido': 'JARA'}
# Nombre: MARIA MARTA DE AGUIRRE RAMIREZ, Response: {'nombres': 'MARIA MARTA', 'primer_apellido': 'DE AGUIRRE', 'segundo_apellido': 'RAMIREZ'}
# Nombre: MARIA PILAR DANOBEITIA ESTADES, Response: {'nombres': 'MARIA PILAR', 'primer_apellido': 'DANOBEITIA', 'segundo_apellido': 'ESTADES'}
# Nombre: ALVARO SAIEH BENDECK, Response: {'nombres': 'ALVARO', 'primer_apellido': 'SAIEH', 'segundo_apellido': 'BENDECK'}
# Nombre: MARIA FRANCISCA SAIEH GUZMAN, Response: {'nombres': 'MARIA FRANCISCA', 'primer_apellido': 'SAIEH', 'segundo_apellido': 'GUZMAN'}
# Nombre: JUAN PABLO VEGA WALKER, Response: {'nombres': 'JUAN PABLO', 'primer_apellido': 'VEGA', 'segundo_apellido': 'WALKER'}
# Nombre: FERNANDO DEL SOLAR CONCHA, Response: {'nombres': 'FERNANDO', 'primer_apellido': 'DEL SOLAR', 'segundo_apellido': 'CONCHA'}
# Nombre: JORGE ALEJANDRO ALVAREZ ARAVENA, Response: {'nombres': 'JORGE ALEJANDRO', 'primer_apellido': 'ALVAREZ', 'segundo_apellido': 'ARAVENA'}
# Nombre: RODRIGO PEREZ MACKENNA, Response: {'nombres': 'RODRIGO', 'primer_apellido': 'PEREZ', 'segundo_apellido': 'MACKENNA'}
# Nombre: JUAN ANDRES OLIVOS BAMBACH, Response: {'nombres': 'JUAN ANDRES', 'primer_apellido': 'OLIVOS', 'segundo_apellido': 'BAMBACH'}
# Nombre: RAUL FRANCISCO SOTOMAYOR VALENZUELA, Response: {'nombres': 'RAUL FRANCISCO', 'primer_apellido': 'SOTOMAYOR', 'segundo_apellido': 'VALENZUELA'}
# Nombre: ABEL BOUCHON SILVA, Response: {'nombres': 'ABEL', 'primer_apellido': 'BOUCHON', 'segundo_apellido': 'SILVA'}
# Nombre: TINA ROSENFELD KREISSELMEYER, Response: {'nombres': 'TINA', 'primer_apellido': 'ROSENFELD', 'segundo_apellido': 'KREISSELMEYER'}
# Nombre: JOSE FRANCISCO SANCHEZ FIGUEROA, Response: {'nombres': 'JOSE FRANCISCO', 'primer_apellido': 'SANCHEZ', 'segundo_apellido': 'FIGUEROA'}
# Nombre: PEDRO PABLO CUEVAS LARRAIN, Response: {'nombres': 'PEDRO PABLO', 'primer_apellido': 'CUEVAS', 'segundo_apellido': 'LARRAIN'}
# Nombre: HORACIO SALAMANCA UBOLDI, Response: {'nombres': 'HORACIO', 'primer_apellido': 'SALAMANCA', 'segundo_apellido': 'UBOLDI'}
# Nombre: JUAN RENDIC LAZO, Response: {'nombres': 'JUAN', 'primer_apellido': 'RENDIC', 'segundo_apellido': 'LAZO'}
# Nombre: ALVARO BARRIGA OLIVA, Response: {'nombres': 'ALVARO', 'primer_apellido': 'BARRIGA', 'segundo_apellido': 'OLIVA'}
# ...
# Nombre: JOSE MIGUEL BARROS VAN HOVELL TOT WESTERFLIER, Response: {'nombres': 'JOSE MIGUEL', 'primer_apellido': 'BARROS', 'segundo_apellido': 'VAN HOVELL TOT WESTERFLIER'}
# Nombre: FERNANDO JOSE LARRAIN CRUZAT, Response: {'nombres': 'FERNANDO JOSE', 'primer_apellido': 'LARRAIN', 'segundo_apellido': 'CRUZAT'}
# Nombre: RODRIGO GAZITUA ZAVALA, Response: {'nombres': 'RODRIGO', 'primer_apellido': 'GAZITUA', 'segundo_apellido': 'ZAVALA'}
# Nombre: GUILLERMO UNDURRAGA ECHEVERRIA, Response: {'nombres': 'GUILLERMO', 'primer_apellido': 'UNDURRAGA', 'segundo_apellido': 'ECHEVERRIA'}
# Nombre: SERGIO GERMAN ACEVEDO CAMPOS, Response: {'nombres': 'SERGIO GERMAN', 'primer_apellido': 'ACEVEDO', 'segundo_apellido': 'CAMPOS'}
# Nombre: FRANCIS STENNING DE LA VALLE, Response: {'nombres': 'FRANCIS', 'primer_apellido': 'STENNING', 'segundo_apellido': 'DE LA VALLE'}
# Nombre: JOSE FERNANDO ROMERO TAPIA, Response: {'nombres': 'JOSE FERNANDO', 'primer_apellido': 'ROMERO', 'segundo_apellido': 'TAPIA'}
# Nombre: GABRIEL RODRIGUEZ BLAS, Response: {'nombres': 'GABRIEL', 'primer_apellido': 'RODRIGUEZ', 'segundo_apellido': 'BLAS'}
# Nombre: FRANCISCO IGNACIO ALAMOS ROJAS, Response: {'nombres': 'FRANCISCO IGNACIO', 'primer_apellido': 'ALAMOS', 'segundo_apellido': 'ROJAS'}
# Nombre: GABRIEL RODRIGUEZ BAS, Response: {'nombres': 'GABRIEL', 'primer_apellido': 'RODRIGUEZ', 'segundo_apellido': 'BAS'}
# Nombre: CARLOS ALFONSO CASTILLO CLARO, Response: {'nombres': 'CARLOS ALFONSO', 'primer_apellido': 'CASTILLO', 'segundo_apellido': 'CLARO'}
# Nombre: TOMAS BOTTIGER MULLER, Response: {'nombres': 'TOMAS', 'primer_apellido': 'BOTTIGER', 'segundo_apellido': 'MULLER'}
# Nombre: FRANCIS STENNING DE LAVALLE, Response: {'nombres': 'FRANCIS', 'primer_apellido': 'STENNING', 'segundo_apellido': 'DE LAVALLE'}
# Nombre: ANDRES SANTA CRUZ LOPEZ, Response: {'nombres': 'ANDRES', 'primer_apellido': 'SANTA CRUZ', 'segundo_apellido': 'LOPEZ'}
# Nombre: HERNAN URIBE GABLER, Response: {'nombres': 'HERNAN URIBE', 'primer_apellido': 'GABLER', 'segundo_apellido': ''}
# Nombre: FELIPE LAMARCA CLARO, Response: {'nombres': 'FELIPE', 'primer_apellido': 'LAMARCA', 'segundo_apellido': 'CLARO'}
# Nombre: ANDRES CALDERON VOLOCHINSKY, Response: {'nombres': 'ANDRES', 'primer_apellido': 'CALDERON', 'segundo_apellido': 'VOLOCHINSKY'}
# Nombre: MICHEL CALDERON VOLOCHINSKY, Response: {'nombres': 'MICHEL', 'primer_apellido': 'CALDERON', 'segundo_apellido': 'VOLOCHINSKY'}
# Nombre: CARLOS JORGE RENATO RAMIREZ FERNANDEZ, Response: {'nombres': 'CARLOS JORGE RENATO', 'primer_apellido': 'RAMIREZ', 'segundo_apellido': 'FERNANDEZ'}
# Nombre: ISABEL MARGARITA BRAVO COLLAO, Response: {'nombres': 'ISABEL MARGARITA', 'primer_apellido': 'BRAVO', 'segundo_apellido': 'COLLAO'}
# Nombre: VERONICA EDWARDS GUZMAN, Response: {'nombres': 'VERONICA', 'primer_apellido': 'EDWARDS', 'segundo_apellido': 'GUZMAN'}
# Nombre: SANDRA PORCILE ROJAS, Response: {'nombres': 'SANDRA', 'primer_apellido': 'PORCILE', 'segundo_apellido': 'ROJAS'}
# Nombre: LAURENCE GOLBORNE RIVEROS, Response: {'nombres': 'LAURENCE', 'primer_apellido': 'GOLBORNE', 'segundo_apellido': 'RIVEROS'}
# Nombre: JOSE ANDRES BARRIGA FEHRMAN, Response: {'nombres': 'JOSE ANDRES', 'primer_apellido': 'BARRIGA', 'segundo_apellido': 'FEHRMAN'}
# Nombre: DEBORA CALDERON KOHON, Response: {'nombres': 'DEBORA', 'primer_apellido': 'CALDERON', 'segundo_apellido': 'KOHON'}
# Nombre: ALEJANDRO ANDRES ROSEMBLATT KIBLISKY, Response: {'nombres': 'ALEJANDRO ANDRES', 'primer_apellido': 'ROSEMBLATT', 'segundo_apellido': 'KIBLISKY'}
# Nombre: MAURICIO EUGENIO BALBONTIN ORYAN, Response: {'nombres': 'MAURICIO EUGENIO', 'primer_apellido': 'BALBONTIN', 'segundo_apellido': 'ORYAN'}
# Nombre: GUSTAVO ALCALDE LEMARIE, Response: {'nombres': 'GUSTAVO', 'primer_apellido': 'ALCALDE', 'segundo_apellido': 'LEMARIE'}
# Nombre: FELIPE GUILLERMO MORANDE LAVIN, Response: {'nombres': 'FELIPE GUILLERMO', 'primer_apellido': 'MORANDE', 'segundo_apellido': 'LAVIN'}
# Nombre: JULIO GALVEZ BOIZARD, Response: {'nombres': 'JULIO', 'primer_apellido': 'GALVEZ', 'segundo_apellido': 'BOIZARD'}
# Nombre: SERGIO HENRIQUEZ DIAZ, Response: {'nombres': 'SERGIO', 'primer_apellido': 'HENRIQUEZ', 'segundo_apellido': 'DIAZ'}
# Nombre: EDUARDO BITRAN COLODRO, Response: {'nombres': 'EDUARDO', 'primer_apellido': 'BITRAN', 'segundo_apellido': 'COLODRO'}
# Nombre: JORGE ROSENBLUT RATINOFF, Response: {'nombres': 'JORGE', 'primer_apellido': 'ROSENBLUT', 'segundo_apellido': 'RATINOFF'}
# Nombre: JUAN PABLO MATUS PICKERING, Response: {'nombres': 'JUAN PABLO', 'primer_apellido': 'MATUS', 'segundo_apellido': 'PICKERING'}
# Nombre: JOSE LUIS LETELIER AZZARI, Response: {'nombres': 'JOSE LUIS', 'primer_apellido': 'LETELIER', 'segundo_apellido': 'AZZARI'}
# Nombre: DAVID ANDRES FARCAS GUENDELMAN, Response: {'nombres': 'DAVID ANDRES', 'primer_apellido': 'FARCAS', 'segundo_apellido': 'GUENDELMAN'}
# Nombre: ALVARO MAURICIO ROSENBLUT GORODINSKY, Response: {'nombres': 'ALVARO MAURICIO', 'primer_apellido': 'ROSENBLUT', 'segundo_apellido': 'GORODINSKY'}
# Nombre: JOSE MIGUEL BARROS VAN HOVELL TOT WESTERFLIER, Response: {'nombres': 'JOSE MIGUEL', 'primer_apellido': 'BARROS', 'segundo_apellido': 'VAN HOVELL TOT WESTERFLIER'}
# Nombre: GUILLERMO UNDURRAGA ECHEVERRIA, Response: {'nombres': 'GUILLERMO', 'primer_apellido': 'UNDURRAGA', 'segundo_apellido': 'ECHEVERRIA'}
# Nombre: JUAN CARLOS UNDURRAGA VARELA, Response: {'nombres': 'JUAN CARLOS', 'primer_apellido': 'UNDURRAGA', 'segundo_apellido': 'VARELA'}
# Nombre: RAIMUNDO FERNANDO SILVA MARTINO, Response: {'nombres': 'RAIMUNDO FERNANDO', 'primer_apellido': 'SILVA', 'segundo_apellido': 'MARTINO'}
# Nombre: FRANCISCO JAVIER VALDIVIA BERNSTEIN, Response: {'nombres': 'FRANCISCO JAVIER', 'primer_apellido': 'VALDIVIA', 'segundo_apellido': 'BERNSTEIN'}
# Nombre: SANTIAGO VIAL ECHEVERRIA, Response: {'nombres': 'SANTIAGO', 'primer_apellido': 'VIAL', 'segundo_apellido': 'ECHEVERRIA'}
# Nombre: YAKOB ANIBAL MOSA SHMES, Response: {'nombres': 'YAKOB ANIBAL', 'primer_apellido': 'MOSA', 'segundo_apellido': 'SHMES'}
# Nombre: GABRIEL RUIZ TAGLE CORREA, Response: {'nombres': 'GABRIEL', 'primer_apellido': 'RUIZ TAGLE', 'segundo_apellido': 'CORREA'}
# Nombre: ARTURO SALAH CASSANI, Response: {'nombres': 'ARTURO', 'primer_apellido': 'SALAH', 'segundo_apellido': 'CASSANI'}
# Nombre: CARLOS TAPIA SIEGLITZ, Response: {'nombres': 'CARLOS', 'primer_apellido': 'TAPIA', 'segundo_apellido': 'SIEGLITZ'}
# Nombre: HAROLD MAYNENICHOLLS SECUL, Response: {'nombres': 'HAROLD', 'primer_apellido': 'MAYNENICHOLLS', 'segundo_apellido': 'SECUL'}
# Nombre: LEONARDO BATTAGLIA CASTRO, Response: {'nombres': 'LEONARDO', 'primer_apellido': 'BATTAGLIA', 'segundo_apellido': 'CASTRO'}
# Nombre: PABLO ALEJANDRO ACCHIARDI LAGOS, Response: {'nombres': 'PABLO ALEJANDRO', 'primer_apellido': 'ACCHIARDI', 'segundo_apellido': 'LAGOS'}
# Nombre: PAUL ERNESTO FONTAINE BENAVIDES, Response: {'nombres': 'PAUL ERNESTO', 'primer_apellido': 'FONTAINE', 'segundo_apellido': 'BENAVIDES'}
# Nombre: ANDRES VICUNA GARCIAHUIDOBRO, Response: {'nombres': 'ANDRES VICUNA', 'primer_apellido': 'GARCIAHUIDOBRO', 'segundo_apellido': ''}
# Nombre: ALEJANDRO ASCUI ROBLES, Response: {'nombres': 'ALEJANDRO', 'primer_apellido': 'ASCUI', 'segundo_apellido': 'ROBLES'}
# Nombre: ALFREDO STOHWING LEISHNER, Response: {'nombres': 'ALFREDO', 'primer_apellido': 'STOHWING', 'segundo_apellido': 'LEISHNER'}
# Nombre: ANGEL MAULEN RIOS, Response: {'nombres': 'ANGEL MAULEN', 'primer_apellido': 'RIOS', 'segundo_apellido': ''}
# Nombre: CARLOS CORTES GUZMAN, Response: {'nombres': 'CARLOS', 'primer_apellido': 'CORTES', 'segundo_apellido': 'GUZMAN'}
# Nombre: DIEGO GONZALEZ RIEDEMANN, Response: {'nombres': 'DIEGO', 'primer_apellido': 'GONZALEZ', 'segundo_apellido': 'RIEDEMANN'}
# Nombre: JOSE MIGUEL SANHUEZA DE LA CRUZ, Response: {'nombres': 'JOSE MIGUEL', 'primer_apellido': 'SANHUEZA', 'segundo_apellido': 'DE LA CRUZ'}
# Nombre: EDMUNDO JOSE VALLADARES HOJAS, Response: {'nombres': 'EDMUNDO JOSE', 'primer_apellido': 'VALLADARES', 'segundo_apellido': 'HOJAS'}
# Nombre: PABLO ANDRES MORALES AHUMADA, Response: {'nombres': 'PABLO ANDRES', 'primer_apellido': 'MORALES', 'segundo_apellido': 'AHUMADA'}
# Nombre: LEONIDAS VIAL ECHEVERRIA, Response: {'nombres': 'LEONIDAS', 'primer_apellido': 'VIAL', 'segundo_apellido': 'ECHEVERRIA'}
# Nombre: JOSE MIGUEL JIMENEZ KRZEMINSKI, Response: {'nombres': 'JOSE MIGUEL', 'primer_apellido': 'JIMENEZ', 'segundo_apellido': 'KRZEMINSKI'}
# Nombre: JAIME PIZARRO HERRERA, Response: {'nombres': 'JAIME', 'primer_apellido': 'PIZARRO', 'segundo_apellido': 'HERRERA'}
# Nombre: ALFONSO GOMEZ MORALES, Response: {'nombres': 'ALFONSO', 'primer_apellido': 'GOMEZ', 'segundo_apellido': 'MORALES'}
# Nombre: PALOMA MILLARAY NORAMBUENA CARDENAS, Response: {'nombres': 'PALOMA MILLARAY', 'primer_apellido': 'NORAMBUENA', 'segundo_apellido': 'CARDENAS'}
# Nombre: ALEJANDRO JAAZIEL ZUNIGA DROGUETT, Response: {'nombres': 'ALEJANDRO JAAZIEL', 'primer_apellido': 'ZUNIGA', 'segundo_apellido': 'DROGUETT'}
# Nombre: PEDRO GRAU BONET, Response: {'nombres': 'PEDRO', 'primer_apellido': 'GRAU', 'segundo_apellido': 'BONET'}
# Nombre: RICHARD ALEXANDER FRANJOLA BUSTOS, Response: {'nombres': 'RICHARD ALEXANDER', 'primer_apellido': 'FRANJOLA', 'segundo_apellido': 'BUSTOS'}
# Nombre: CARLOS CASZELY GARRIDO, Response: {'nombres': 'CARLOS', 'primer_apellido': 'CASZELY', 'segundo_apellido': 'GARRIDO'}
# Nombre: WALTER OLIVA MUNIZAGA, Response: {'nombres': 'WALTER OLIVA', 'primer_apellido': 'MUNIZAGA', 'segundo_apellido': ''}
# Nombre: JOSE TOMAS ERRAZURIZ GREZ, Response: {'nombres': 'JOSE TOMAS', 'primer_apellido': 'ERRAZURIZ', 'segundo_apellido': 'GREZ'}
# Nombre: PATRICIO ROJAS RAMOS, Response: {'nombres': 'PATRICIO', 'primer_apellido': 'ROJAS', 'segundo_apellido': 'RAMOS'}
# Nombre: VANINA ANABALON CORREA, Response: {'nombres': 'VANINA ANABALON', 'primer_apellido': 'CORREA', 'segundo_apellido': ''}
# Nombre: OSVALDO BAEZA LIZAMA, Response: {'nombres': 'OSVALDO', 'primer_apellido': 'BAEZA', 'segundo_apellido': 'LIZAMA'}
# Nombre: HERNAN LEVY ARENSBURG, Response: {'nombres': 'HERNAN', 'primer_apellido': 'LEVY', 'segundo_apellido': 'ARENSBURG'}
# Nombre: EDUARDO LOYOLA OSORIO, Response: {'nombres': 'EDUARDO', 'primer_apellido': 'LOYOLA', 'segundo_apellido': 'OSORIO'}
# Nombre:   , Response: {'nombres': '', 'primer_apellido': '', 'segundo_apellido': ''}
# Nombre: RAFAEL ANDRES MARIN JORDAN, Response: {'nombres': 'RAFAEL ANDRES', 'primer_apellido': 'MARIN', 'segundo_apellido': 'JORDAN'}
# Nombre: CARLOS BAUDRAND SAAVEDRA, Response: {'nombres': 'CARLOS', 'primer_apellido': 'BAUDRAND', 'segundo_apellido': 'SAAVEDRA'}
# Nombre: JASON TILROE , Response: {'nombres': 'JASON', 'primer_apellido': 'TILROE', 'segundo_apellido': ''}
# Nombre: JAMES PRUSKY , Response: {'nombres': 'JAMES', 'primer_apellido': 'PRUSKY', 'segundo_apellido': ''}
# Nombre: OSWALDO SANDOVAL ZAVALA, Response: {'nombres': 'OSWALDO', 'primer_apellido': 'SANDOVAL', 'segundo_apellido': 'ZAVALA'}
# Nombre: RUSSELL SCHREIBER , Response: {'nombres': 'RUSSELL', 'primer_apellido': 'SCHREIBER', 'segundo_apellido': ''}
# Nombre: ALEJANDRO ARTURO ARIAS WURSLIN, Response: {'nombres': 'ALEJANDRO ARTURO', 'primer_apellido': 'ARIAS', 'segundo_apellido': 'WURSLIN'}
# Nombre: JOSE ANTONIO MARIN JORDAN, Response: {'nombres': 'JOSE ANTONIO', 'primer_apellido': 'MARIN', 'segundo_apellido': 'JORDAN'}
# Nombre: ADRIAN GOSTUSKI , Response: {'nombres': 'ADRIAN', 'primer_apellido': 'GOSTUSKI', 'segundo_apellido': ''}
# Nombre: HOWARD GAUNT , Response: {'nombres': 'HOWARD', 'primer_apellido': 'GAUNT', 'segundo_apellido': ''}
# Nombre: LUIS IGNACIO MARIN JORDAN, Response: {'nombres': 'LUIS IGNACIO', 'primer_apellido': 'MARIN', 'segundo_apellido': 'JORDAN'}
# Nombre: FRANCISCO JAVIER MARIN ALAMOS, Response: {'nombres': 'FRANCISCO JAVIER', 'primer_apellido': 'MARIN', 'segundo_apellido': 'ALAMOS'}
# Nombre: FRANCISCO JAVIER MARIN JORDAN, Response: {'nombres': 'FRANCISCO JAVIER', 'primer_apellido': 'MARIN', 'segundo_apellido': 'JORDAN'}
# Nombre: EDUARDO GUILLERMO JUNGE PUMPIN, Response: {'nombres': 'EDUARDO GUILLERMO', 'primer_apellido': 'JUNGE', 'segundo_apellido': 'PUMPIN'}
# Nombre: FELIPE ALLENDE DECOMBE, Response: {'nombres': 'FELIPE', 'primer_apellido': 'ALLENDE', 'segundo_apellido': 'DECOMBE'}
# Nombre: JULIO BONIFACIO , Response: {'nombres': 'JULIO BONIFACIO', 'primer_apellido': '', 'segundo_apellido': ''}
# Nombre: SIMON LAY , Response: {'nombres': 'SIMON', 'primer_apellido': 'LAY', 'segundo_apellido': ''}
# Nombre: JUAN EDUARDO ERRAZURIZ OSSA, Response: {'nombres': 'JUAN EDUARDO', 'primer_apellido': 'ERRAZURIZ', 'segundo_apellido': 'OSSA'}
# Nombre: NAOSHI MATSUMOTO TAKAHASHI, Response: {'nombres': 'NAOSHI', 'primer_apellido': 'MATSUMOTO', 'segundo_apellido': 'TAKAHASHI'}
# Nombre: HORACIO NOLBERTO PAVEZ GARCIA, Response: {'nombres': 'HORACIO NOLBERTO', 'primer_apellido': 'PAVEZ', 'segundo_apellido': 'GARCIA'}
# Nombre: NORMAN HANSEN FERNANDEZ, Response: {'nombres': 'NORMAN', 'primer_apellido': 'HANSEN', 'segundo_apellido': 'FERNANDEZ'}
# Nombre: SILVIO ROSTAGNO HAYES, Response: {'nombres': 'SILVIO', 'primer_apellido': 'ROSTAGNO', 'segundo_apellido': 'HAYES'}
# Nombre: LUIS FELIPE CERON CERON, Response: {'nombres': 'LUIS FELIPE', 'primer_apellido': 'CERON', 'segundo_apellido': 'CERON'}
# Nombre: JAIME ANDRES VARGAS SERRANO, Response: {'nombres': 'JAIME ANDRES', 'primer_apellido': 'VARGAS', 'segundo_apellido': 'SERRANO'}
# Nombre: HORACIO PAVEZ ARO, Response: {'nombres': 'HORACIO', 'primer_apellido': 'PAVEZ', 'segundo_apellido': 'ARO'}
# Nombre: NORMAN HANSEN ROSES, Response: {'nombres': 'NORMAN', 'primer_apellido': 'HANSEN', 'segundo_apellido': 'ROSES'}
# Nombre: CANIO CORBO LIOI, Response: {'nombres': 'CANIO', 'primer_apellido': 'CORBO', 'segundo_apellido': 'LIOI'}
# Nombre: JUAN ANDRES FONTAINE TALAVERA, Response: {'nombres': 'JUAN ANDRES', 'primer_apellido': 'FONTAINE', 'segundo_apellido': 'TALAVERA'}
# Nombre: MARIO ALFREDO SANTANDER GARCIA, Response: {'nombres': 'MARIO ALFREDO', 'primer_apellido': 'SANTANDER', 'segundo_apellido': 'GARCIA'}
# Nombre: JOSE RAMON ABOITIZ DOMINGUEZ, Response: {'nombres': 'JOSE RAMON', 'primer_apellido': 'ABOITIZ', 'segundo_apellido': 'DOMINGUEZ'}
# C:\Users\lucas\AppData\Local\Temp\ipykernel_12676\3271963171.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_names_df_without_duplicates['Nombres'] = nombres
# C:\Users\lucas\AppData\Local\Temp\ipykernel_12676\3271963171.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_names_df_without_duplicates['Primer_apellido'] = primer_apellidos
# C:\Users\lucas\AppData\Local\Temp\ipykernel_12676\3271963171.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_names_df_without_duplicates['Segundo_apellido'] = segundo_apellidos
#                         Nombre                   Nombre_empresa  Nombres  \
# 0     LUIS ORVANANOS LASCURAIN  CORPORACION GEO, S.A.B. DE C.V.     LUIS
# 1  EMILIO CUENCA FRIEDERICHSEN  CORPORACION GEO, S.A.B. DE C.V.   EMILIO
# 2      ROBERTO ORVANANOS CONDE  CORPORACION GEO, S.A.B. DE C.V.  ROBERTO
# 3     INIGO ORVANANOS CORCUERA  CORPORACION GEO, S.A.B. DE C.V.    INIGO
# 4          RAUL ZORRILLA COSIO  CORPORACION GEO, S.A.B. DE C.V.     RAUL
#
#   Primer_apellido Segundo_apellido
# 0       ORVANANOS        LASCURAIN
# 1          CUENCA    FRIEDERICHSEN
# 2       ORVANANOS            CONDE
# 3       ORVANANOS         CORCUERA
# 4        ZORRILLA            COSIO

# %%
company_names_df_without_duplicates.to_csv('data/directors_and_companies_separated.csv', index=False)
